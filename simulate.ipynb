# %%
import csv
from collections import defaultdict

connections = defaultdict(dict)

with open('simulation/simulation.csv', 'r') as f:
    reader = csv.reader(f)
    next(reader)
    for row in reader:
        metric = row[1]
        
        connections[metric]["type"] = "metric"
        connections[metric]['inputs'] = []  # Make it a list for multiple inputs
        connections[metric]['outputs'] = []
        connections[metric]['min'] = float(row[4]) if row[4] else None
        connections[metric]['max'] = float(row[5]) if row[5] else None
        connections[metric]['default'] = float(row[3]) if row[6] else None

        hash_indices = [i for i, x in enumerate(row) if x == '#']

        if len(hash_indices) > 1 and row[hash_indices[1] + 1]:
            input_formulas = row[hash_indices[1] + 1:hash_indices[2]] if len(hash_indices) > 2 else row[hash_indices[1] + 1:]
            for input_formula in input_formulas:
                if ',' in input_formula:
                    input_metric, input_equation = input_formula.split(',', 1)
                    connections[metric]['inputs'].append({'name': input_metric, 'equation': input_equation.split(',')[0]})  # Append to list

        if len(hash_indices) > 2:
            for output_formula in row[hash_indices[2] + 1:]:
                if output_formula and ',' in output_formula:
                    output_metric, output_equation = output_formula.split(',', 1)
                    connections[metric]['outputs'].append({'name': output_metric, 'equation': output_equation.split(',')[0]})

metrics = connections
metrics["WorkerProductivity"]
# Out:
# {'type': 'metric',
#  'inputs': [],
#  'outputs': [{'name': 'GDP', 'equation': '0.35*(x^0.76)'},
#   {'name': 'InternationalTrade', 'equation': '-0.2+(0.4*x)'},
#   {'name': 'Unemployment', 'equation': '-0.08+(0.16*x)'}],
#  'min': 0.0,
#  'max': 1.0,
#  'default': 0.45}

# %%
from collections import defaultdict
import csv

# Initialize a dictionary to hold the policy effects
policy_effects = defaultdict(list)

# Read the CSV file and map the effects
with open('simulation/policies.csv', 'r') as f:
    reader = csv.reader(f)
    next(reader)  # Skip the header
    for row in reader:
        policy_name = row[1]  # The policy name is in the second column
        if row[10].startswith('_prereq_sovereign'):
            continue

        # Find the index of '#Effects' to locate policy effects
        try:
            effects_start_idx = row.index('#Effects') + 1
        except ValueError:
            continue

        # Parse the output effects and add to the dictionary
        for effect in row[effects_start_idx:]:
            if effect and ',' in effect:
                effect_metric, effect_equation = effect.split(',', 1)
                policy_effects[policy_name].append({'name': effect_metric, 'equation': effect_equation})

policy_effects
len(policy_effects)
# Out:
# 266

# %%
# Initialize a dictionary to hold all relationships
all_relationships = defaultdict(lambda: {'inputs': [], 'outputs': []})

# Populate relationships from metrics
for metric, details in connections.items():
    all_relationships[metric]["type"] = "metric"
    all_relationships[metric]["min"] = details['min']
    all_relationships[metric]["max"] = details['max']
    all_relationships[metric]["default"] = details['default']

    # Handle input
    input_details = details.get('inputs', [])
    if input_details:
        for input_ in input_details:
            input_metric = input_['name']
            all_relationships[metric]['inputs'].append({
                'name': input_metric,
                'equation': input_['equation']
            })

    # Handle outputs
    output_details = details.get('outputs', [])
    if output_details:
        for output in output_details:
            output_metric = output['name']
            all_relationships[metric]['outputs'].append({
                'name': output_metric,
                'equation': output['equation'].split(',')[0]
            })

# Populate relationships from policy effects
for policy, effects in policy_effects.items():
    if effects:
        for effect in effects:
            effect_metric = effect['name']
            all_relationships[policy]["type"] = "policy"
            all_relationships[policy]['outputs'].append({
                'name': effect_metric,
                'equation': effect['equation'].split(',')[0]
            })

# Now, all_relationships contains all the interconnected relationships
all_relationships["WorkerProductivity"]
# Out:
# {'inputs': [],
#  'outputs': [{'name': 'GDP', 'equation': '0.35*(x^0.76)'},
#   {'name': 'InternationalTrade', 'equation': '-0.2+(0.4*x)'},
#   {'name': 'Unemployment', 'equation': '-0.08+(0.16*x)'}],
#  'type': 'metric',
#  'min': 0.0,
#  'max': 1.0,
#  'default': 0.45}

# %%
import csv

situations = {}

# Open the situations.csv file and read its content
with open('simulation/situations.csv', 'r') as f:
    reader = csv.reader(f)
    next(reader)  # Skip the header row

    for row in reader:
        if all(x == '' for x in row):
            continue  # Skip empty rows

        name = row[1]
        if name in ["Monarchy", "NorthKorea", "NorthWestPassage", "Malaria", "MineralWealth", "OilWealth"]:
            continue
        
        positive = True if row[5] == '1' else False
        start_trigger_value = float(row[6])
        stop_trigger_value = float(row[7])

        # Initialize empty dictionaries for inputs and outputs
        situations[name] = {
            'positive': positive, 
            'start_trigger_value': start_trigger_value, 
            'stop_trigger_value': stop_trigger_value, 
            'inputs': [], 
            'outputs': []
        }

        # Find indices of '#' to separate inputs and outputs
        hash_indices = [i for i, x in enumerate(row) if x == '#']

        # Handle inputs if they exist
        if len(hash_indices) > 0:
            for input_formula in row[hash_indices[0] + 1:hash_indices[1]]:
                if input_formula and ',' in input_formula:
                    input_metric, input_equation = input_formula.split(',', 1)
                    situations[name]['inputs'].append({'type': 'metric', 'name': input_metric, 'equation': input_equation.split(',')[0]})

        # Handle outputs if they exist
        if len(hash_indices) > 1:
            for output_formula in row[hash_indices[1] + 1:]:
                if output_formula and ',' in output_formula:
                    output_metric, output_equation = output_formula.split(',', 1)
                    situations[name]['outputs'].append({'type': 'metric', 'name':output_metric, 'equation': output_equation.split(',')[0]})

# Assuming all_relationships, metrics, policy_effects, and situations are already defined
for situation_name, situation_data in situations.items():
    all_relationships[situation_name] = {
        'type': 'situation',
        'inputs': situation_data['inputs'],
        'outputs': situation_data['outputs'],
        'start_trigger': situation_data['start_trigger_value'],
        'stop_trigger': situation_data['stop_trigger_value'],
    }

# %%
from scipy.optimize import minimize
import re
from pyswarm import pso


# Utility function to evaluate an equation safely
def evaluate_equation(equation, x_value, policy_values, metrics_values, metric_name, all_relationships, in_progress):
    equation = equation.replace('^', '**')
    equation = equation.replace('x', str(x_value))
    
    for match in re.findall(r'\b([a-zA-Z_]+)\b', equation):
        if match in policy_values:
            equation = equation.replace(match, str(policy_values[match]))
        elif match in metrics_values:
            equation = equation.replace(match, str(metrics_values[match]))
        else:
            computed_value = compute_metric(match, all_relationships, policy_values, metrics_values, in_progress=in_progress)
            metrics_values[match] = computed_value
            equation = equation.replace(match, str(computed_value))

    try:
        res = 0
        if isinstance(res, complex):
            res = 0  # Replace with your real-world behavior
        res = round(eval(equation), 2)
        return res

    except Exception as e:
        raise ValueError(f"Error in evaluating equation: {e}")


# Recursive function to compute the value of a target metric
MAX_DEPTH = 100  # Maximum recursion depth to avoid infinite loops
debug_info = []

def compute_metric(target, all_relationships, policy_values, metrics_values, depth=0, in_progress=None, reset_metrics=None):   
    global debug_info     
    if in_progress is None:
        in_progress = set()
        
    if target in ["_globaleconomy_", "_default_", "_year"]:
        return 0.5
    
    if reset_metrics is not None and target in reset_metrics:
        metrics_values.pop(target, None)
        
    if target in in_progress or depth > MAX_DEPTH:
        if target in metrics_values:
            return metrics_values[target]
        if target in policy_values:
            return policy_values[target]
        
        return 0

    in_progress.add(target)
    value = all_relationships.get(target, {}).get('default', 0)

    if target in metrics_values:
        return metrics_values[target]
    
    if target in policy_values:
        return policy_values[target]

    inputs = all_relationships.get(target, {}).get('inputs', [])
    for inp in inputs:
        metric_name = inp['name']
        equation = inp['equation']
        input_value = compute_metric(metric_name, all_relationships, policy_values, metrics_values, depth + 1, in_progress, reset_metrics)
        if not metric_name in list(situations.keys()) or (metric_name in list(situations.keys()) and input_value >= all_relationships[metric_name]['start_trigger']):
            eq_value = evaluate_equation(equation, input_value, policy_values, metrics_values, metric_name, all_relationships, in_progress)
            value += round(eq_value, 2)
            metrics_values[target] = value
        
            if target in DEBUG_VALUE:
                debug_info.append((metric_name, input_value, eq_value, target))


    for key, rel in all_relationships.items():
        outputs = rel.get('outputs', [])
        for output in outputs:
            if output['name'] == target:
                metric_name = key
                equation = output['equation']
                input_value = compute_metric(metric_name, all_relationships, policy_values, metrics_values, depth + 1, in_progress, reset_metrics)
                
                if not metric_name in list(situations.keys()) or (metric_name in list(situations.keys()) and input_value >= all_relationships[metric_name]['start_trigger']):
                    eq_value = evaluate_equation(equation, input_value, policy_values, metrics_values, metric_name, all_relationships, in_progress)
                    value += round(eq_value, 2)
                    metrics_values[target] = value
                
                    if target in DEBUG_VALUE:
                        debug_info.append((metric_name, input_value, eq_value, target))

    min_val = all_relationships.get(target, {}).get('min', 0)
    max_val = all_relationships.get(target, {}).get('max', 1)

    res = round(value, 2)
    if target in DEBUG_VALUE:
        debug_info.sort(key=lambda x: x[2], reverse=True)
        for metric_name, input_value, eq_value, target in debug_info:
            print(f"Metric: {metric_name} (for {target}), Input: {input_value}, Impact: {eq_value}")
        print(f"Final Calculation for {target}: {res}")
        debug_info = []
        
    if res < min_val:
        res = min_val
    elif res > max_val:
        res = max_val
    metrics_values[target] = res
    if reset_metrics is not None and target in reset_metrics:
        reset_metrics.remove(target)
    in_progress.remove(target)

    return res

# Function to find all connected factors to a given target metric
def find_connected_factors(target, all_relationships, connected_factors):
    if target in connected_factors:
        return
    connected_factors.add(target)
    
    # Search upstream (where target is an input)
    inputs = all_relationships.get(target, {}).get('inputs', [])
    for inp in inputs:
        find_connected_factors(inp['name'], all_relationships, connected_factors)
    
    # Search downstream (where target is an output)
    for key, rel in all_relationships.items():
        outputs = rel.get('outputs', [])
        for output in outputs:
            if output['name'] == target:
                find_connected_factors(key, all_relationships, connected_factors)

import random

def debug_situations(all_relationships, situations, policy_values, rerun_number=2, initial_metrics_values=None):
    metrics_values = initial_metrics_values if initial_metrics_values is not None else {}
    metrics_values.update({"_globaleconomy_": 0.5, "_default_": 0.5, "_year": 0.5})

    reset_metrics = None

    for i in range(rerun_number):
        situation_score = 0
        good_situations = []
        bad_situations = []
        for situation, attributes in situations.items():
            situation_value = compute_metric(situation, all_relationships, policy_values, metrics_values, reset_metrics=reset_metrics)
            if situation_value >= all_relationships[situation]['start_trigger']:
                situation_score += 1 if attributes['positive'] else -1
                (good_situations if attributes['positive'] else bad_situations).append((situation, situation_value))
                        
        reset_metrics = set(metrics_values.keys())

    print("Good Situations (" + str(len(good_situations)) + "):", good_situations)
    print("Bad Situations (" + str(len(bad_situations)) + "):", bad_situations)
    print("Difference Score:", situation_score)
    return metrics_values

DEBUG_VALUE = [""]
policy_values = {key: round(random.uniform(0, 1), 2) for key in all_relationships if all_relationships[key].get('type') == 'policy'}
metrics_values = debug_situations(all_relationships, situations, policy_values)
# Out:
# Good Situations (1): [('EgalitarianSociety', 1)]
# Bad Situations (10): [('TechnologyBackwater', 0.61), ('TeacherShortage', 1), ('BrainDrain', 1), ('TaxEvasion', 0.93), ('DroneWars', 1), ('LudditeRiots', 0.99), ('ForeignIntelligenceInterference', 1), ('Polarization', 1.0), ('FakeNews', 1), ('MediaMonopolies', 0.64)]
# Difference Score: -9

# %%
all_relationships["EUContribution"]
# Out:
# {'type': 'situation',
#  'inputs': [{'type': 'metric',
#    'name': 'ForeignRelations',
#    'equation': '0-(0.1*x)'}],
#  'outputs': [{'type': 'metric',
#    'name': 'Patriot_freq',
#    'equation': '-0.05-(0*x)'},
#   {'type': 'metric', 'name': 'Patriot', 'equation': '-0.05-(0*x)'},
#   {'type': 'metric', 'name': 'InternationalTrade', 'equation': '0.1+(0*x)'},
#   {'type': 'metric', 'name': 'Stability', 'equation': '0+(0.1*x)'},
#   {'type': 'metric', 'name': 'ForeignInvestment', 'equation': '0+(0.1*x)'}],
#  'start_trigger': 0.011,
#  'stop_trigger': -1.0}

# %%
from pyswarm import pso

def optimize_situations(all_relationships, situations):
    last_10_scores = []
    last_100_scores = []

    def objective_function_pso(x, *args):
        nonlocal last_10_scores, last_100_scores
        policy_values = {key: round(x[i], 2) for i, key in enumerate(policy_factors)}
        metrics_values = {"_globaleconomy_": 0.5, "_default_": 0.5, "_year": 0.5}
        situation_score = 0
        reset_metrics = None

        for i in range(2):
            situation_score = 0
            for situation, attributes in situations.items():
                situation_value = compute_metric(situation, all_relationships, policy_values, metrics_values, reset_metrics=reset_metrics)
                if situation_value >= all_relationships[situation]['start_trigger']:
                    if attributes['positive']:
                        situation_score -= 1  # Minimize the negative to maximize positives
                            
            reset_metrics = set(metrics_values.keys())

        last_10_scores.append(situation_score)
        last_100_scores.append(situation_score)
        
        if len(last_10_scores) > 10:
            last_10_scores.pop(0)
            
        if len(last_100_scores) > 100:
            last_100_scores.pop(0)
        
        avg_10 = round(sum(last_10_scores) / len(last_10_scores), 2)    
        avg_100 = round(sum(last_100_scores) / len(last_100_scores), 2)
        
        print(f"Current Score: {situation_score}, Avg last 10: {avg_10}, Avg last 100: {avg_100}")        
        return situation_score 
    
    positive_situations = [name for name, data in situations.items() if data['positive']]
    negative_situations = [name for name, data in situations.items() if not data['positive']]

    all_connected_factors = set()
    for situation in positive_situations + negative_situations:
        find_connected_factors(situation, all_relationships, all_connected_factors)

    policy_factors = [factor for factor in all_connected_factors if all_relationships[factor].get('type') == 'policy']
    
    lb = [0 for _ in policy_factors]
    ub = [1 for _ in policy_factors]

    xopt, fopt = pso(objective_function_pso, lb, ub, args=(), swarmsize=100, omega=0.5, phip=0.5, phig=1.0, maxiter=10000, minstep=0.01, minfunc=0.01, debug=False)

    optimized_values = {key: xopt[i] for i, key in enumerate(policy_factors)}
    changed_metrics = []
    untouched_metrics = []
    good_situations = []
    bad_situations = []

    for key, value in optimized_values.items():
        if abs(value - 0.5) > 1e-4:
            changed_metrics.append((key, value))
        else:
            untouched_metrics.append(key)
            
    reset_metrics = None
            
    for i in range(2):
        situation_score = 0
        for situation, attributes in situations.items():
            situation_value = compute_metric(situation, all_relationships, optimized_values, metrics_values, reset_metrics=reset_metrics)
            if situation_value >= all_relationships[situation]['start_trigger']:
                situation_score += 1 if attributes['positive'] else -1
                (good_situations if attributes['positive'] else bad_situations).append((situation, situation_value))
                
        reset_metrics = set(metrics_values.keys())

    final_score = -fopt

    return optimized_values, changed_metrics, untouched_metrics, final_score, good_situations, bad_situations
    

optimized_values, changed_metrics, untouched_metrics, final_score, good_situations, bad_situations = optimize_situations(
    all_relationships, situations)
print("Changed Metrics:", changed_metrics)
print("Good Situations:", good_situations)
print("Bad Situations:", bad_situations)
print("Final Score:", final_score)
# Out:
# Current Score: -1, Avg last 10: -1.0, Avg last 100: -1.0
# Current Score: -1, Avg last 10: -1.0, Avg last 100: -1.0
# Current Score: -1, Avg last 10: -1.0, Avg last 100: -1.0
# Current Score: -2, Avg last 10: -1.25, Avg last 100: -1.25
# Current Score: -1, Avg last 10: -1.2, Avg last 100: -1.2
# Current Score: -3, Avg last 10: -1.5, Avg last 100: -1.5
# Current Score: -1, Avg last 10: -1.43, Avg last 100: -1.43
# Current Score: 0, Avg last 10: -1.25, Avg last 100: -1.25
# Current Score: -2, Avg last 10: -1.33, Avg last 100: -1.33
# Current Score: -2, Avg last 10: -1.4, Avg last 100: -1.4
# Current Score: -2, Avg last 10: -1.5, Avg last 100: -1.45
# Current Score: -2, Avg last 10: -1.6, Avg last 100: -1.5
# Current Score: -3, Avg last 10: -1.8, Avg last 100: -1.62
# Current Score: -1, Avg last 10: -1.7, Avg last 100: -1.57
# Current Score: -1, Avg last 10: -1.7, Avg last 100: -1.53
# Current Score: -1, Avg last 10: -1.5, Avg last 100: -1.5
# Current Score: -1, Avg last 10: -1.5, Avg last 100: -1.47
# Current Score: -2, Avg last 10: -1.7, Avg last 100: -1.5
# Current Score: -2, Avg last 10: -1.7, Avg last 100: -1.53
# Current Score: -2, Avg last 10: -1.7, Avg last 100: -1.55
# Current Score: -3, Avg last 10: -1.8, Avg last 100: -1.62
# Current Score: -2, Avg last 10: -1.8, Avg last 100: -1.64
# Current Score: -2, Avg last 10: -1.7, Avg last 100: -1.65
# Current Score: -2, Avg last 10: -1.8, Avg last 100: -1.67
# Current Score: -2, Avg last 10: -1.9, Avg last 100: -1.68
# Current Score: -3, Avg last 10: -2.1, Avg last 100: -1.73
# Current Score: -1, Avg last 10: -2.1, Avg last 100: -1.7
# Current Score: -2, Avg last 10: -2.1, Avg last 100: -1.71
# Current Score: -2, Avg last 10: -2.1, Avg last 100: -1.72
# Current Score: -3, Avg last 10: -2.2, Avg last 100: -1.77
# Current Score: -2, Avg last 10: -2.1, Avg last 100: -1.77
# Current Score: -2, Avg last 10: -2.1, Avg last 100: -1.78
# Current Score: -3, Avg last 10: -2.2, Avg last 100: -1.82
# Current Score: -1, Avg last 10: -2.1, Avg last 100: -1.79
# Current Score: -1, Avg last 10: -2.0, Avg last 100: -1.77
# Current Score: -2, Avg last 10: -1.9, Avg last 100: -1
# Current Score: -4, Avg last 10: -4.2, Avg last 100: -4.06
# Current Score: -4, Avg last 10: -4.2, Avg last 100: -4.05
# Current Score: -4, Avg last 10: -4.3, Avg last 100: -4.05
# Current Score: -4, Avg last 10: -4.2, Avg last 100: -4.04
# Current Score: -2, Avg last 10: -3.9, Avg last 100: -4.02
# Current Score: -5, Avg last 10: -3.9, Avg last 100: -4.02
# Current Score: -4, Avg last 10: -3.8, Avg last 100: -4.02
# Current Score: -4, Avg last 10: -3.8, Avg last 100: -4.02
# Current Score: -4, Avg last 10: -3.8, Avg last 100: -4.02
# ...
# Current Score: -3, Avg last 10: -4.6, Avg last 100: -4.79
# Current Score: -5, Avg last 10: -4.6, Avg last 100: -4.79
# Current Score: -5, Avg last 10: -4.6, Avg last 100: -4.79
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.79
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.79
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.79
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.79
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.79
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.79
# Current Score: -4, Avg last 10: -4.7, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.9, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.9, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.9, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.9, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.9, Avg last 100: -4.8
# Current Score: -3, Avg last 10: -4.7, Avg last 100: -4.78
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.79
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.79
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.79
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.79
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -5.0, Avg last 100: -4.8
# Current Score: -4, Avg last 10: -4.9, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.9, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.9, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.9, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.9, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.9, Avg last 100: -4.8
# Current Score: -5, Avg last 10: -4.9, Avg last 100: -4.8
# Current Score: -4, Avg last 10: -4.8, Avg last 100: -4.79
# Current Score: -4, Avg last 10: -4.7, Avg last 100: -4.78
# Current Score: -4, Avg last 10: -4.6, Avg last 100: -4.78
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.78
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.78
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.78
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.78
# Current Score: -4, Avg last 10: -4.6, Avg last 100: -4.77
# Current Score: -5, Avg last 10: -4.6, Avg last 100: -4.77
# Current Score: -5, Avg last 10: -4.6, Avg last 100: -4.78
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.78
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.78
# Current Score: -5, Avg last 10: -4.9, Avg last 100: -4.78
# Current Score: -4, Avg last 10: -4.8, Avg last 100: -4.79
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.79
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.79
# Current Score: -4, Avg last 10: -4.7, Avg last 100: -4.78
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.78
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.78
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.78
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.78
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.78
# Current Score: -4, Avg last 10: -4.7, Avg last 100: -4.78
# Current Score: -4, Avg last 10: -4.7, Avg last 100: -4.78
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.78
# Current Score: -4, Avg last 10: -4.6, Avg last 100: -4.77
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.77
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.77
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.77
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.77
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.77
# Current Score: -5, Avg last 10: -4.7, Avg last 100: -4.77
# Current Score: -5, Avg last 10: -4.8, Avg last 100: -4.78
# {'CompulsorySchoolSports': 0.0, 'TechnologyGrants': 0.44, 'InternationalFusionResearchProject': 0.41, 'NeedleExchangeProgram': 0.29, 'Compulsorychurchattendance': 0.04, 'CarbonTax': 0.46, 'SmartMeterProgram': 0.38, 'MilitarySpending': 1.0, 'Diversityquotasforcompanies': 0.6, 'GenderDiscriminationAct': 0.75, 'CityFarms': 1.0, 'Narcotics': 0.47, 'PrisonerVoting': 0.73, 'CongestionCharging': 0.73, 'BiofuelSubsidies': 0.67, 'ConsumerRights': 0.82, 'BicycleSubsidies': 0.16, 'CCTVCameras': 1.0, 'ChildBenefit': 0.18, 'FrequentFlyerTax': 0.3, 'Banforeignchurchservice': 0.63, 'HybridCarsInitiative': 0.36, 'NuclearFission': 0.16, 'Forcepoliticalmilitaryreligiousoath': 1.0, 'WaterCannon': 0.44, 'CarEmmissionsLimits': 0.0, 'EmptyHomesTax': 0.09, 'Banprivateeducation': 0.24, 'RoboticsResearch': 0.56, 'LegaliseProstitution': 0.54, 'BusSubsidies': 1.0, 'Prisons': 0.87, 'ArmedPolice': 0.63, 'statereligion': 0.0, 'RoadBuilding': 0.69, 'AbortionLaw': 0.47, 'RightToDie': 0.0, 'EnterpriseInvestmentScheme': 1.0, 'KeepTheCountryTidyCampaign': 0.23, 'GenderTransition': 0.7, 'StateSchools': 0.0, 'PoliceDrones': 0.0, 'MansionTax': 0.05, 'UniversityGrants': 0.95, 'LabourLaws': 1.0, 'YouthPoliticsCouncil': 1.0, 'SolidarityTax': 0.74, 'SchoolTaxCredits': 1.0, 'TollRoads': 0.94, 'TelecommutingInitiative': 0.0, 'PrisonerTagging': 0.44, 'FinancialTransactionsTax': 0.85, 'Cyberbullyingawarenesscampaign': 1.0, 'NuclearWeapons': 0.14, 'PayrollTax': 0.77, 'workersdividend': 0.69, 'PetrolTax': 0.19, 'RubberBullets': 0.47, 'FamilyPlanning': 0.82, 'LimitAutomatedTrading': 0.0, 'Banprivatehealthcare': 0.69, 'AntibioticsBan': 0.56, 'StatePostService': 1.0, 'SpeedCameras': 0.99, 'Punitivewealthtax': 0.69, 'DiplomaticService': 0.57, 'MarriedTaxAllowance': 0.0, 'NationalBusinessCouncil': 0.43, 'ExecutiveTermLimit': 0.28, 'UniversalBasicIncome': 0.07, 'JudiciaryIndependence': 0.52, 'AgricultureSubsidies': 0.43, 'bantobacco': 0.58, 'DetentionWithoutTrial': 0.38, 'ScienceFunding':
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=78'>79</a>     return optimized_values, changed_metrics, untouched_metrics, final_score, good_situations, bad_situations
# ---> <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=81'>82</a> optimized_values, changed_metrics, untouched_metrics, final_score, good_situations, bad_situations = optimize_situations(
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=82'>83</a>     all_relationships, situations)
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=83'>84</a> print("Changed Metrics:", changed_metrics)
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=84'>85</a> print("Good Situations:", good_situations)
#
# c:\Users\alexa\OneDrive\Documents\Cloud\political-ai\map.ipynb Cell 7 line optimize_situations(all_relationships, situations)
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=47'>48</a> lb = [0 for _ in policy_factors]
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=48'>49</a> ub = [1 for _ in policy_factors]
# ---> <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=50'>51</a> xopt, fopt = pso(objective_function_pso, lb, ub, args=(), swarmsize=100, omega=0.5, phip=0.5, phig=1.0, maxiter=10000, minstep=0.01, minfunc=0.01, debug=False)
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=52'>53</a> optimized_values = {key: xopt[i] for i, key in enumerate(policy_factors)}
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=53'>54</a> changed_metrics = []
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyswarm\pso.py:145, in pso(func, lb, ub, ieqcons, f_ieqcons, args, kwargs, swarmsize, omega, phip, phig, maxiter, minstep, minfunc, debug)
#     143 x[i, mark1] = lb[mark1]
#     144 x[i, mark2] = ub[mark2]
# --> 145 fx = obj(x[i, :])
#     147 # Compare particle's best position (if constraints are satisfied)
#     148 if fx<fp[i] and is_feasible(x[i, :]):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\pyswarm\pso.py:74, in pso.<locals>.<lambda>(x)
#      71 vlow = -vhigh
#      73 # Check for constraint function(s) #########################################
# ---> 74 obj = lambda x: func(x, *args, **kwargs)
#      75 if f_ieqcons is None:
#      76     if not len(ieqcons):
#
# c:\Users\alexa\OneDrive\Documents\Cloud\political-ai\map.ipynb Cell 7 line optimize_situations.<locals>.objective_function_pso(x, *args)
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=30'>31</a>     last_100_scores.pop(0)
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=32'>33</a> avg_10 = round(sum(last_10_scores) / len(last_10_scores), 2)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=33'>34</a> avg_100 = round(sum(last_100_scores) / len(last_100_scores), 2)
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=35'>36</a> print(f"Current Score: {situation_score}, Avg last 10: {avg_10}, Avg last 100: {avg_100}")
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=36'>37</a> return situation_score
#
# c:\Users\alexa\OneDrive\Documents\Cloud\political-ai\map.ipynb Cell 7 line optimize_situations.<locals>.objective_function_pso(x, *args)
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=30'>31</a>     last_100_scores.pop(0)
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=32'>33</a> avg_10 = round(sum(last_10_scores) / len(last_10_scores), 2)
# ---> <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=33'>34</a> avg_100 = round(sum(last_100_scores) / len(last_100_scores), 2)
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=35'>36</a> print(f"Current Score: {situation_score}, Avg last 10: {avg_10}, Avg last 100: {avg_100}")
#      <a href='vscode-notebook-cell:/c%3A/Users/alexa/OneDrive/Documents/Cloud/political-ai/map.ipynb#W6sZmlsZQ%3D%3D?line=36'>37</a> return situation_score
#
# File _pydevd_bundle/pydevd_cython.pyx:1443, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle/pydevd_cython.pyx:700, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1143, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:1134, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle/pydevd_cython.pyx:311, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\debugpy\_vendored\pydevd\pydevd.py:2062, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2059             from_this_thread.append(frame_custom_thread_id)
#    2061     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, stop_reason):
# -> 2062         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2064 frames_list = None
#    2066 if keep_suspended:
#    2067     # This means that we should pause again after a set next statement.
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\debugpy\_vendored\pydevd\pydevd.py:2098, in PyDB._do_wait_suspend(self, thread, frame, event, arg, suspend_type, from_this_thread, frames_tracker)
#    2095         self._call_input_hook()
#    2097     self.process_internal_commands()
# -> 2098     time.sleep(0.01)
#    2100 self.cancel_async_evaluation(get_current_thread_id(thread), str(id(frame)))
#    2102 # process any stepping instructions
#
# KeyboardInterrupt:

# %%
policy_values
# Out:
# {'AbortionLaw': 0.68,
#  'AdultEducationSubsidies': 0.62,
#  'AgricultureSubsidies': 0.91,
#  'AirlineTax': 0.09,
#  'AlcoholAwarenessCampaign': 0.72,
#  'AlcoholLaw': 0.29,
#  'AlcoholTax': 0.65,
#  'AntibioticsBan': 0.5,
#  'AntiCorruptionAgency': 0.66,
#  'ArmedPolice': 0.53,
#  'ArtsSubsidies': 0.6,
#  'AutomationTax': 0.77,
#  'BanCoal': 0.53,
#  'Bandivorce': 0.59,
#  'Banforeignchurchservice': 0.23,
#  'Banhomosexuality': 0.95,
#  'Banlowmpgcars': 0.52,
#  'Banprivateeducation': 0.28,
#  'Banprivatehealthcare': 0.1,
#  'BanSecondHomeOwnership': 0.93,
#  'BanSundayShopping': 0.92,
#  'BicycleSubsidies': 0.69,
#  'BiofuelSubsidies': 0.62,
#  'BodyCameras': 0.14,
#  'BorderControls': 0.58,
#  'BorderWall': 0.7,
#  'BusinessStartupCampaign': 0.95,
#  'BusLanes': 0.56,
#  'BusSubsidies': 0.07,
#  'CapCEOPayMultiplier': 0.16,
#  'CapitalGainsTax': 0.65,
#  'CarbonCaptureAndStorage': 0.95,
#  'CarbonTax': 0.63,
#  'CarEmmissionsLimits': 0.56,
#  'CarPoolingCampaign': 0.08,
#  'CarTax': 0.49,
#  'CCTVCameras': 0.22,
#  'CharityTaxRelief': 0.79,
#  'ChildBenefit': 0.63,
#  'ChildcareProvision': 0.24,
#  'CitizenshipTests': 0.88,
#  'CityFarms': 0.2,
#  'CleanEnergySubsidies': 0.62,
#  'CleanFuelSubsidy': 0.23,
#  'ClimateChangeAdaptionFund': 0.01,
#  'Closeairportscompletely': 0.01,
#  'CommunityPolicing': 0.77,
#  'Compulsorychurchattendance': 0.54,
#  'CompulsoryFoodLabelling': 0.89,
#  'CompulsoryForeignLanguageClasses': 0.14,
#  'Compulsorylanguagelessons': 0.84,
#  'CompulsorySchoolSports': 0.8,
#  'Compulsoryworkfortheunemployed ': 0.06,
#  'CongestionCharging': 0.89,
#  'ConsumerRights': 0.95,
#  'CorporationTax': 0.76,
#  'Creationism': 0.98,
#  'Curfews': 0.23,
#  'Cyberbullyingawarenesscampaign': 0.45,
#  'CyclingCampaign': 0.92,
#  'DeathPenalty': 0.94,
#  'DetentionWithoutTrial': 0.94,
#  'DiplomaticService': 0.85,
#  'DisabilityBenefit': 0.73,
#  'Diversityquotasforcompanies': 0.93,
#  'DivertedProfitsTax': 0.56,
#  'DriverlessCarLaws': 0.17,
#  'DroneStrikeAct': 0.06,
#  'DrugEnforcement': 0.95,
#  'DrugTreatment': 0.86,
#  'EcoHomeRegulations': 0.15,
#  'ElectricCarsInitiative': 0.78,
#  'EmptyHomesTax': 0.61,
#  'EnterpriseInvestmentScheme': 0.68,
#  'ExecutiveTermLength': 0.1,
#  'ExecutiveTermLimit': 0.9,
#  'FaithSchoolSubsidies': 0.38,
#  'FamilyPlanning': 0.85,
#  'FemaleGenitalMutilationBan': 0.68,
#  'FinancialTransactionsTax': 0.67,
#  'Flagsoneverystreetcorner': 0.51,
#  'FlatTax': 0.67,
#  'FoodStamps': 0.73,
#  'FoodStandards': 0.78,
#  'Forcepoliticalmilitaryreligiousoath': 0.29,
#  'ForeignAid': 0.06,
#  'ForeignInvestmentRestrictions': 0.98,
#  'ForeignInvestorTaxBreaks': 0.85,
#  'FreeBusPasses': 0.75,
#  'FreeEyeTests': 0.95,
#  'FreeParentingClasses': 0.73,
#  'FreeSchoolMeals': 0.33,
#  'FrequentFlyerTax': 0.35,
#  'FuelEfficiency': 0.6,
#  'Gambling': 0.86,
#  'GameHunting': 0.95,
#  'GatedCommunities': 0.77,
#  'GayMarriage': 0.44,
#  'GenderDiscriminationAct': 0.27,
#  'GenderTransition': 0.47,
#  'GeneralMediaCensorship': 0.74,
#  'GovernmentSubsidiesForUnions': 0.37,
#  'GraduateTax': 0.95,
#  'GreenElectronicsInitiative': 0.2,
#  'HandgunLaws': 0.01,
#  'HealthcareVouchers': 0.29,
#  'HealthFoodSubsidies': 0.45,
#  'HealthTaxCredits': 0.44,
#  'HealthyEatingCampaign': 0.04,
#  'HumanCloningResearchGrants': 0.97,
#  'HybridCarsInitiative': 0.08,
#  'IDCards': 0.19,
#  'IncomeTax': 0.1,
#  'InheritanceTax': 0.93,
#  'IntellectualPropertyRights': 0.78,
#  'IntelligenceServices': 0.53,
#  'InternationalFusionResearchProject': 0.95,
#  'InternetCensorship': 0.68,
#  'InternetCurrencyTaxation': 0.82,
#  'InternetTax': 0.04,
#  'JudiciaryIndependence': 0.26,
#  'JunkFoodTax': 0.63,
#  'JuryTrial': 0.27,
#  'KeepTheCountryTidyCampaign': 0.8,
#  'LaborDayBankHoliday': 0.41,
#  'LabourLaws': 0.35,
#  'LegalAid': 0.62,
#  'LegaliseProstitution': 0.06,
#  'LimitAutomatedTrading': 0.47,
#  'Limitorbancarsincities': 0.02,
#  'LuxuryGoodsTax': 0.74,
#  'MandatoryMicrochipImplant': 0.27,
#  'Mandatorymicrogeneration': 0.98,
#  'MansionTax': 0.26,
#  'MarriedTaxAllowance': 0.42,
#  'MarsProgram': 0.66,
#  'MaternityLeave': 0.35,
#  'MicrogenerationGrants': 0.91,
#  'MilitarySpending': 0.62,
#  'MinimumWage': 0.45,
#  'Monorail': 0.79,
#  'MortgageTaxRelief': 0.42,
#  'Narcotics': 0.27,
#  'Nationalanthematstartofnews': 0.94,
#  'Nationalanthemsinschool': 0.86,
#  'NationalArmedForcesWeek': 0.68,
#  'NationalBusinessCouncil': 0.53,
#  'NationalService': 0.95,
#  'NeedleExchangeProgram': 0.14,
#  'Newcarsubsidies': 0.55,
#  'NuclearFission': 0.81,
#  'OilDrillingSubsidy': 0.34,
#  'OneChildPolicy': 0.49,
#  'OrganDonation': 0.49,
#  'OrganicSubsidy': 0.01,
#  'PayrollTax': 0.56,
#  'PetrolTax': 0.05,
#  'PhoneTapping': 0.03,
#  'PlasticBagTax': 0.04,
#  'PoliceDrones': 0.14,
#  'PoliceForce': 0.73,
#  'PollutionControls': 0.18,
#  'PressFreedom': 0.84,
#  'PrisonerTagging': 0.09,
#  'PrisonerVoting': 0.64,
#  'PrisonRegime': 0.13,
#  'Prisons': 0.58,
#  'PrivatePrisons': 0.14,
#  'PropertyTax': 0.21,
#  'ProportionalFines': 0.68,
#  'PublicLibraries': 0.44,
#  'Publicreligiousbroadcasts': 0.02,
#  'Publictaxreturns': 0.69,
#  'Punitivetaxonsuperstores': 0.6,
#  'Punitivewealthtax': 0.24,
#  'RaceDiscriminationAct': 0.56,
#  'RacialProfiling': 0.1,
#  'RareEarthRefinement': 0.97,
#  'RecreationalDrugsTax': 0.38,
#  'Recycling': 0.07,
#  'Reforestation': 0.84,
#  'RentControls': 0.38,
#  'RetirementAge': 0.19,
#  'RightToDie': 0.83,
#  'RightToPrivacy': 0.52,
#  'RoadBuilding': 0.85,
#  'RoboticsResearch': 0.43,
#  'RubberBullets': 0.84,
#  'RuralDevelopmentGrants': 0.52,
#  'SalesTax': 0.75,
#  'SateliteRoadPricing': 0.17,
#  'SchoolBuses': 0.65,
#  'SchoolPrayers': 0.61,
#  'SchoolTaxCredits': 0.58,
#  'SchoolVouchers': 0.29,
#  'ScienceFunding': 0.65,
#  'SecretCourts': 0.24,
#  'SelectiveSchooling': 0.39,
#  'SmallBusinessGrants': 0.66,
#  'SmartMeterProgram': 0.62,
#  'SocialCare': 0.57,
#  'SocialJusticeFoundation': 0.36,
#  'SpaceProgram': 0.51,
#  'SpeedCameras': 0.26,
#  'StampOutRacismWeek': 0.66,
#  'StateAirline': 0.46,
#  'StateBroadcaster': 0.42,
#  'StateEnergy': 0.01,
#  'StateHealthService': 0.18,
#  'StateHousing': 0.63,
#  'StatePensions': 0.57,
#  'StatePostService': 0.83,
#  'StateRail': 0.39,
#  'StateSchools': 0.49,
#  'StateTelecoms': 0.05,
#  'StateWater': 0.7,
#  'StemCells': 0.58,
#  'SyntheticMeatResearchGrants': 0.42,
#  'Tasers': 0.03,
#  'TaxShelters': 0.57,
#  'TearGas': 0.69,
#  'TechnologyColleges': 0.48,
#  'TechnologyGrants': 0.04,
#  'TelecommutingInitiative': 0.4,
#  'TobaccoAwarenessCampaign': 0.74,
#  'TobaccoTax': 0.61,
#  'TollRoads': 0.88,
#  'TortureUsageBySecretServices': 0.16,
#  'TourismAdCampaign': 0.83,
#  'TradeCouncil': 0.57,
#  'Tradeunionbansatcompanies': 0.6,
#  'UnemployedBenefit': 0.56,
#  'UniversalBasicIncome': 0.1,
#  'UniversityGrants': 0.92,
#  'VerticalFarmSubsidies': 0.29,
#  'WaterCannon': 0.36,
#  'WelfareFraudDept': 0.15,
#  'WinterFuelSubsidy': 0.1,
#  'WitnessProtectionProgram': 0.11,
#  'WorkersOnBoards': 0.88,
#  'WorkSafetyLaw': 0.62,
#  'YoungEntrepreneurScheme': 0.0,
#  'YouthClubSubsidies': 0.62,
#  'YouthPoliticsCouncil': 0.93,
#  'SolidarityTax': 0.74,
#  'CitizenshipForSale': 0.89,
#  'ImmigrationRules': 0.2,
#  'RefugeePolicy': 0.36,
#  'banwomendriving': 0.06,
#  'religioustax': 0.03,
#  'religiousbanknotes': 0.11,
#  'statereligion': 0.12,
#  'desalination': 0.76,
#  'watermeters': 0.16,
#  'plasticstax': 0.14,
#  'packagingtax': 0.4,
#  'unexplainedwealth': 0.12,
#  'competitionlaw': 0.55,
#  'bordernavy': 0.46,
#  'NuclearWeapons': 0.27,
#  'co2campaign': 0.67,
#  'banalcohol': 0.42,
#  'bantobacco': 0.9,
#  'bancrypto': 0.29,
#  'workersdividend': 0.05,
#  'bansocialmedia': 0.14}

# %%
import json

# Read pre-set policy values from JSON file
with open('results/pso/minimize_negative-2.json', 'r') as f:
    preset_policy_values = json.load(f)

# Initialize an empty dictionary for metrics values
initial_metrics_values = {"_globaleconomy_": 0.5, "_default_": 0.5, "_year": 0.5}

# Run the computations twice and print the results
metrics_values = debug_situations(all_relationships, situations, preset_policy_values, 3, initial_metrics_values)

print("Metrics Values:", metrics_values)
# Out:
# Good Situations (3): [('EgalitarianSociety', 1), ('EndangeredSpecies', 0.47), ('PrivateSpaceProgram', 0.67)]
# Bad Situations (2): [('DroneWars', 1), ('ForeignIntelligenceInterference', 1)]
# Difference Score: 1
# Metrics Values: {'_globaleconomy_': 0.5, '_default_': 0.5, '_year': 0.5, 'Retired_perc': 0, '_inv_ElectricCarTransition': 0, 'Poor_perc': 0, 'PrivateHousing': 0.0, 'Capitalist_perc': 0, 'Emigration': 0.53, 'IndustrialAutomation': 0.63, 'Technology': 0.61, 'PrivateEnergy': 0.0, 'PrivateHealthcare': 0.6, 'PrivateRail': 0.0, 'PrivateSchools': 1.0, 'PrivateTelecoms': 0.0, 'PrivateWater': 0.0, '_global_interest_rates_': 0, '_effectivedebt_': 0, 'Inflation': 0.2, 'EUContribution': 0.0, 'EUSubsidies': 0.0, 'EUMonetaryPolicy': 0, 'DebtCrisis': 0.0, 'Patriot_perc': 0, 'ExtremeNationalism': 0, 'ForeignRelations': 0.34, 'GenerationalWealthGap': 0.36, 'PrivatePensions': 0.12, 'Ghettos': 0, 'VigilanteMobs': 0, 'Homelessness': 0, 'WorkingWeek': 0.68, 'FakeNews': 0.59, 'InternetSpeed': 0.37, 'MediaMonopolies': 0.36, 'Pollution': 0, 'Environment': 1.0, '_MiddleIncome': -0.11, 'RailUsage': 0.17, 'DriverlessCars': 0, 'BusUsage': 0.77, 'PetrolProtests': 0, 'Corruption': 0.33, 'Organised Crime': 0.57, 'InternetCurrencyAdoption': 0.0, 'Young': 0, 'CyberBullying': 0, 'Erasmus': 0, 'Hyperinflation': 0, 'BlackMarket': 0, 'IllegalImmigration': 0.0, 'IllegalImmigrationCrisis': 0.0, 'ForeignIntelligenceInterference': 1, 'CurrencyStrength': 0.0, 'OilDemand': 0.0, 'ElectricCarTransition': 0.87, 'Environmentalist_perc': 0, 'RareEarthPrice': 0.0, 'Rareearthcrisis': 0.0, 'EnergyEfficiency': 0.89, 'CarUsage': 0.0, 'OilPrice': 0.63, 'OilSupply': 0.59, 'GigEconomy': 0.09, 'InternationalTrade': 0.34, 'Alcoholism': 0, 'Cyclones': 0.4, 'Watershortage': 0, '_winning_': 0, 'Farmers_perc': 0, 'Veganism': 0.6, 'FoodPrice': 0.28, 'TobaccoUse': 0.0, 'HospitalOvercrowding': 0.44, 'HealthcareDemand': 0.36, 'Obesity': 0, 'AsthmaEpidemic': 0.16, 'Lifespan': 0.26, 'Tourism': 0.33, 'AntisocialBehaviour': 0.03, 'Religious_perc': 0, 'Foodcrisis': 0.23, 'ClassWarfare': 0, 'EndangeredSpecies': 0.47, 'HIVAIDS': 0, 'DoctorsStrike': 0.36, '_prereq_': 0, 'TradeUnionist_perc': 0, 'ContagiousDisease': 0, 'ExtremePoverty': 0, 'Antibiotics-ResitantBacteria': 0, 'FemaleGenitalMutilation': 0.02, 'PowerBlackouts': 0, 'GeneralStrike': 0, 'Socialist_perc': 0, 'Health': 1.0, 'InnerCityRiots': 0, 'RaceRiots': 0, 'EthnicMinorities_perc': 0, 'LudditeRiots': 0.36, 'ViolentCrimeRate': 0.0, 'MentalHealth': 0.0, 'SocialMediaAddiction': 0, 'DrugAddiction': 0.52, 'PrisonOvercrowding': 0, 'StreetGangs': 0, 'Equality': 1.0, 'TaxEvasion': 0.25, 'InternetCrime': 0, 'CyberWarfare': 0, 'EgalitarianSociety': 1, 'GenderEquality': 0.22, 'CrimeRate': 0.0, 'DroneWars': 1, 'Liberal_perc': 0, 'ArmedReligiousCommunities': 0, 'Religious': 0, 'RacialTension': 0.41, '_global_liberalism': 0, 'LegalDrugConsumption': 0.13, 'AlcoholConsumption': 0.0, 'WorkerProductivity': 0.39, 'TechnologicalAdvantage': 0.57, 'BrainDrain': 0.08, 'Bureaucracy': 0.01, 'Unemployment': 0.63, 'CorporateExodus': 0.55, 'Population': 0.35, 'Realestatebubble': 0, '_LowIncome': 0.09, 'AirTravel': 0.0, 'CO2Emissions': 0.0, 'TrafficCongestion': 0.0, 'EnvironmentalProtests': 0.2, 'AverageTemperature': 0.01, 'GlobalCO2': 0.01, 'ImmigrationDemand': 0.26, 'Immigration': 0.01, 'Wages': 0.45, 'HighProductivity': 0.14, 'HumanDevelopment': 0.48, 'ForeignAidReceived': 0.03, 'Democracy': 0.87, 'PovertyRate': 0.0, 'Stability': 1.0, 'Young_perc': 0, '_Terrorism': 0.0, 'BusinessConfidence': 0.82, 'ForeignInvestment': 0.45, 'Uncompetitive Economy': 0.51, 'ImportTarrifs': 0, 'TechnologyBackwater': 0.34, 'Rail Strike': 0.23, 'Gridlock': 0.0, 'PrivateSpaceProgram': 0.67, 'GDP': 0.7, '_HighIncome': -0.5, 'Charity': 0.0, 'Education': 0.99, 'TeachersStrike': 0, 'TeacherShortage': 0.42, 'SkillsShortage': 0.3, 'ArmedRobbery': 0, 'MultinationalTaxEvasion': 0, 'FoodBanks': 0, 'EmergencyPowers': 0, 'Polarization': 0}

# %%
import json

# Read JSON
filename= "results/run-3-negative.json"
with open(filename, "r") as f:
    data = json.load(f)

# Sort keys
sorted_data = {k: data[k] for k in sorted(data.keys())}

# Write JSON
with open(filename, "w") as f:
    json.dump(sorted_data, f, indent=4)

# %%
from collections import defaultdict
from itertools import combinations
import numpy as np
import os
import json

# Load all JSON data
all_data = []
for filename in os.listdir("results/pso"):
    if filename.endswith(".json"):
        with open(f"results/pso/{filename}", "r") as f:
            data = json.load(f)
            all_data.append(data)

# Initialize dictionaries
all_agree = {}
some_agree = {}
disagree = {}

# Check each policy key
for key in all_data[0].keys():
    values = np.array([d[key] for d in all_data])
    n_files = len(values)

    agreement_count = defaultdict(int)

    # Compare all combinations of pairs of files
    for i, j in combinations(range(n_files), 2):
        if abs(values[i] - values[j]) <= 0.1:
            agreement_count[i] += 1
            agreement_count[j] += 1

    # Classify based on the number of agreements
    if len(agreement_count) == n_files and all(count == n_files - 1 for count in agreement_count.values()):
        all_agree[key] = values.tolist()
    elif len(agreement_count) >= 2:
        some_agree[key] = values.tolist()
    else:
        disagree[key] = values.tolist()

# %%
all_agree
# Out:
# {'ArmedPolice': [0.63, 0.625, 0.62],
#  'AutomationTax': [0.11, 0.09, 0.07],
#  'BanCoal': [0.07, 0.065, 0.06],
#  'Bandivorce': [0.0, 0.0, 0.0],
#  'CCTVCameras': [1.0, 0.995, 0.99],
#  'CapitalGainsTax': [0.0, 0.0, 0.0],
#  'CarEmmissionsLimits': [0.0, 0.0, 0.0],
#  'CharityTaxRelief': [0.88, 0.9, 0.92],
#  'CitizenshipForSale': [0.0, 0.0, 0.0],
#  'CleanEnergySubsidies': [0.77, 0.7250000000000001, 0.68],
#  'CompulsorySchoolSports': [0.0, 0.0, 0.0],
#  'Compulsoryworkfortheunemployed ': [0.24, 0.21, 0.18],
#  'Cyberbullyingawarenesscampaign': [1.0, 0.98, 0.96],
#  'DeathPenalty': [0.0, 0.03, 0.06],
#  'Diversityquotasforcompanies': [0.6, 0.56, 0.52],
#  'DivertedProfitsTax': [0.71, 0.675, 0.64],
#  'DroneStrikeAct': [0.7, 0.655, 0.61],
#  'EcoHomeRegulations': [0.09, 0.045, 0.0],
#  'ForeignInvestmentRestrictions': [0.19, 0.14500000000000002, 0.1],
#  'FreeBusPasses': [1.0, 1.0, 1.0],
#  'FreeParentingClasses': [0.31, 0.33499999999999996, 0.36],
#  'HealthcareVouchers': [0.9, 0.95, 1.0],
#  'InheritanceTax': [0.2, 0.22, 0.24],
#  'InternationalFusionResearchProject': [0.41, 0.43999999999999995, 0.47],
#  'JudiciaryIndependence': [0.52, 0.48, 0.44],
#  'MaternityLeave': [0.0, 0.0, 0.0],
#  'MilitarySpending': [1.0, 0.97, 0.94],
#  'NeedleExchangeProgram': [0.29, 0.26, 0.23],
#  'OneChildPolicy': [1.0, 0.97, 0.94],
#  'Prisons': [0.87, 0.86, 0.85],
#  'Punitivewealthtax': [0.69, 0.6599999999999999, 0.63],
#  'RetirementAge': [0.23, 0.255, 0.28],
#  'SateliteRoadPricing': [1.0, 0.9550000000000001, 0.91],
#  'SchoolPrayers': [0.47, 0.475, 0.48],
#  'SchoolTaxCredits': [1.0, 0.975, 0.95],
#  'SchoolVouchers': [0.98, 0.99, 1.0],
#  'SelectiveSchooling': [0.0, 0.0, 0.0],
#  'SocialCare': [0.41, 0.365, 0.32],
#  'SpaceProgram': [0.07, 0.035, 0.0],
#  'StampOutRacismWeek': [0.54, 0.535, 0.53],
#  'StateHousing': [0.51, 0.55, 0.59],
#  'TollRoads': [0.94, 0.97, 1.0],
#  'TourismAdCampaign': [0.83, 0.83, 0.83],
#  'WelfareFraudDept': [0.0, 0.0, 0.0],
#  'WorkSafetyLaw': [0.17, 0.17, 0.17],
#  'WorkersOnBoards': [0.01, 0.005, 0.0],
#  'banalcohol': [0.41, 0.43999999999999995, 0.47],
#  'plasticstax': [0.08, 0.13, 0.18],
#  'religiousbanknotes': [0.71, 0.6799999999999999, 0.65],
#  'unexplainedwealth': [0.08, 0.05, 0.02]}

# %%
some_agree
# Out:
# {'AdultEducationSubsidies': [1.0, 0.97, 0.7],
#  'AlcoholAwarenessCampaign': [1.0, 0.8, 0.84],
#  'AlcoholTax': [0.24, 0.0, 0.0],
#  'BanSundayShopping': [0.29, 0.31, 1.0],
#  'Banhomosexuality': [0.71, 0.33, 0.43],
#  'Banlowmpgcars': [0.43, 0.42, 0.71],
#  'Banprivateeducation': [0.24, 0.0, 0.0],
#  'Banprivatehealthcare': [0.69, 0.09, 0.0],
#  'BicycleSubsidies': [0.16, 0.88, 0.82],
#  'BodyCameras': [0.77, 0.55, 0.63],
#  'BorderControls': [0.43, 0.15, 0.25],
#  'BusSubsidies': [1.0, 0.95, 0.32],
#  'CapCEOPayMultiplier': [0.14, 0.1, 0.56],
#  'CarbonCaptureAndStorage': [0.0, 0.02, 0.92],
#  'CarbonTax': [0.46, 1.0, 0.9],
#  'ChildBenefit': [0.18, 1.0, 0.99],
#  'ChildcareProvision': [0.24, 0.55, 0.65],
#  'CityFarms': [1.0, 0.78, 0.84],
#  'ClimateChangeAdaptionFund': [0.84, 0.8, 0.47],
#  'Closeairportscompletely': [0.62, 0.52, 0.4],
#  'CompulsoryForeignLanguageClasses': [0.45, 0.29, 0.32],
#  'CorporationTax': [0.76, 0.0, 0.05],
#  'Creationism': [0.15, 0.07, 1.0],
#  'DetentionWithoutTrial': [0.38, 0.0, 0.0],
#  'DiplomaticService': [0.57, 0.92, 0.96],
#  'DisabilityBenefit': [0.22, 0.36, 0.4],
#  'DriverlessCarLaws': [0.68, 1.0, 0.92],
#  'DrugEnforcement': [0.4, 0.62, 0.56],
#  'ElectricCarsInitiative': [0.63, 0.94, 1.0],
#  'EmptyHomesTax': [0.09, 0.0, 1.0],
#  'ExecutiveTermLength': [0.24, 0.64, 0.63],
#  'FamilyPlanning': [0.82, 1.0, 0.97],
#  'FinancialTransactionsTax': [0.85, 0.97, 1.0],
#  'FoodStamps': [0.59, 0.52, 0.44],
#  'ForeignAid': [0.9, 1.0, 0.58],
#  'ForeignInvestorTaxBreaks': [0.7, 0.6, 0.0],
#  'FrequentFlyerTax': [0.3, 0.0, 0.0],
#  'Gambling': [0.75, 1.0, 1.0],
#  'GayMarriage': [0.15, 1.0, 1.0],
#  'GeneralMediaCensorship': [0.73, 0.77, 1.0],
#  'GovernmentSubsidiesForUnions': [0.67, 0.8, 0.78],
#  'GreenElectronicsInitiative': [0.75, 0.0, 0.05],
#  'HandgunLaws': [0.99, 0.99, 0.11],
#  'IDCards': [0.18, 0.18, 0.33],
#  'InternetTax': [0.04, 0.49, 0.57],
#  'JuryTrial': [0.14, 0.18, 0.49],
#  'Limitorbancarsincities': [0.0, 0.46, 0.49],
#  'MandatoryMicrochipImplant': [0.0, 0.0, 0.11],
#  'Mandatorymicrogeneration': [0.52, 0.02, 0.0],
#  'MansionTax': [0.05, 0.29, 0.3],
#  'MarsProgram': [0.81, 0.82, 0.14],
#  'MinimumWage': [0.37, 0.32, 1.0],
#  'Narcotics': [0.47, 0.82, 0.81],
#  'Nationalanthematstartofnews': [0.69, 0.0, 0.0],
#  'Nationalanthemsinschool': [0.41, 0.0, 0.0],
#  'NuclearFission': [0.16, 0.11, 1.0],
#  'NuclearWeapons': [0.14, 1.0, 1.0],
#  'OilDrillingSubsidy': [0.4, 0.44, 0.0],
#  'OrganDonation': [0.95, 0.99, 0.0],
#  'PublicLibraries': [0.97, 0.73, 0.67],
#  'Publicreligiousbroadcasts': [0.93, 0.86, 0.24],
#  'Publictaxreturns': [0.18, 0.83, 0.84],
#  'RacialProfiling': [0.22, 0.12, 0.65],
#  'RecreationalDrugsTax': [0.12, 0.03, 1.0],
#  'Recycling': [0.06, 0.01, 0.27],
#  'RefugeePolicy': [0.67, 0.44, 0.39],
#  'RentControls': [0.0, 0.01, 1.0],
#  'RightToDie': [0.0, 0.6, 0.65],
#  'RoadBuilding': [0.69, 0.78, 1.0],
#  'RubberBullets': [0.47, 1.0, 1.0],
#  'RuralDevelopmentGrants': [0.64, 0.0, 0.0],
#  'SalesTax': [0.0, 0.15, 0.2],
#  'SchoolBuses': [0.31, 0.31, 0.52],
#  'ScienceFunding': [1.0, 0.94, 0.39],
#  'SecretCourts': [0.2, 0.0, 0.0],
#  'SmallBusinessGrants': [0.41, 0.72, 0.69],
#  'SolidarityTax': [0.74, 1.0, 0.92],
#  'SpeedCameras': [0.99, 0.63, 0.64],
#  'StateAirline': [0.14, 0.18, 0.0],
#  'StateBroadcaster': [0.57, 1.0, 1.0],
#  'StateHealthService': [0.31, 0.0, 0.03],
#  'StatePostService': [1.0, 0.75, 0.65],
#  'StateSchools': [0.0, 0.0, 0.38],
#  'StemCells': [0.38, 0.29, 0.85],
#  'TaxShelters': [0.68, 0.69, 1.0],
#  'TearGas': [1.0, 1.0, 0.16],
#  'TechnologyGrants': [0.44, 0.37, 1.0],
#  'TobaccoAwarenessCampaign': [0.6, 0.55, 0.0],
#  'TradeCouncil': [0.81, 0.1, 0.0],
#  'YouthPoliticsCouncil': [1.0, 0.87, 0.86],
#  'bancrypto': [0.57, 0.96, 1.0],
#  'bansocialmedia': [0.99, 1.0, 0.4],
#  'banwomendriving': [0.91, 1.0, 0.0],
#  'bordernavy': [0.42, 0.01, 0.0],
#  'co2campaign': [0.85, 0.69, 0.67],
#  'competitionlaw': [0.87, 0.96, 0.11],
#  'packagingtax': [1.0, 1.0, 0.31],
#  'watermeters': [0.71, 0.98, 1.0],
#  'workersdividend': [0.69, 0.72, 1.0]}

# %%
disagree
# Out:
# {'AbortionLaw': [0.47, 0.78, 0.0],
#  'AgricultureSubsidies': [0.43, 0.54, 0.19],
#  'AirlineTax': [0.15, 0.44, 0.0],
#  'AlcoholLaw': [0.0, 1.0, 0.74],
#  'AntiCorruptionAgency': [0.56, 0.0, 1.0],
#  'AntibioticsBan': [0.56, 0.74, 1.0],
#  'ArtsSubsidies': [0.19, 0.72, 1.0],
#  'BanSecondHomeOwnership': [0.63, 0.81, 0.27],
#  'Banforeignchurchservice': [0.63, 0.5, 0.1],
#  'BiofuelSubsidies': [0.67, 0.93, 0.29],
#  'BorderWall': [0.39, 0.6, 0.0],
#  'BusLanes': [0.86, 0.73, 0.4],
#  'CarPoolingCampaign': [0.24, 0.08, 0.73],
#  'CarTax': [0.55, 0.21, 0.35],
#  'CitizenshipTests': [0.39, 0.0, 0.86],
#  'CleanFuelSubsidy': [0.98, 0.75, 0.1],
#  'CommunityPolicing': [0.6, 0.91, 0.0],
#  'CompulsoryFoodLabelling': [0.37, 0.8, 0.23],
#  'Compulsorychurchattendance': [0.04, 0.73, 0.99],
#  'Compulsorylanguagelessons': [0.39, 0.99, 0.15],
#  'CongestionCharging': [0.73, 0.0, 1.0],
#  'ConsumerRights': [0.82, 0.61, 0.38],
#  'Curfews': [0.62, 0.36, 1.0],
#  'CyclingCampaign': [0.38, 1.0, 0.54],
#  'DrugTreatment': [0.63, 0.0, 0.29],
#  'EnterpriseInvestmentScheme': [1.0, 0.01, 0.15],
#  'ExecutiveTermLimit': [0.28, 0.63, 0.0],
#  'FaithSchoolSubsidies': [0.4, 0.6, 0.74],
#  'FemaleGenitalMutilationBan': [0.1, 0.75, 0.36],
#  'Flagsoneverystreetcorner': [0.16, 0.69, 1.0],
#  'FlatTax': [1.0, 0.0, 0.63],
#  'FoodStandards': [0.14, 0.0, 0.88],
#  'Forcepoliticalmilitaryreligiousoath': [1.0, 0.66, 0.0],
#  'FreeEyeTests': [0.15, 0.98, 0.42],
#  'FreeSchoolMeals': [0.34, 0.64, 0.95],
#  'FuelEfficiency': [0.45, 0.25, 1.0],
#  'GameHunting': [0.76, 0.96, 0.29],
#  'GatedCommunities': [0.13, 0.43, 0.0],
#  'GenderDiscriminationAct': [0.75, 0.86, 0.0],
#  'GenderTransition': [0.7, 0.07, 0.93],
#  'GraduateTax': [0.5, 0.0, 0.96],
#  'HealthFoodSubsidies': [0.7, 0.07, 0.94],
#  'HealthTaxCredits': [0.44, 0.11, 0.0],
#  'HealthyEatingCampaign': [0.7, 0.0, 1.0],
#  'HumanCloningResearchGrants': [0.48, 0.0, 0.67],
#  'HybridCarsInitiative': [0.36, 0.5, 1.0],
#  'ImmigrationRules': [0.68, 0.0, 0.91],
#  'IncomeTax': [0.46, 0.04, 0.56],
#  'IntellectualPropertyRights': [0.85, 0.01, 0.66],
#  'IntelligenceServices': [0.8, 0.62, 1.0],
#  'InternetCensorship': [0.14, 0.97, 0.45],
#  'InternetCurrencyTaxation': [0.38, 0.81, 0.63],
#  'JunkFoodTax': [0.7, 1.0, 0.84],
#  'KeepTheCountryTidyCampaign': [0.23, 0.0, 0.57],
#  'LaborDayBankHoliday': [0.36, 0.52, 1.0],
#  'LabourLaws': [1.0, 0.33, 0.0],
#  'LegalAid': [0.31, 0.99, 0.09],
#  'LegaliseProstitution': [0.54, 0.05, 1.0],
#  'LimitAutomatedTrading': [0.0, 0.35, 0.5],
#  'LuxuryGoodsTax': [0.04, 0.34, 0.75],
#  'MarriedTaxAllowance': [0.0, 0.69, 1.0],
#  'MicrogenerationGrants': [1.0, 0.01, 0.69],
#  'Monorail': [0.57, 0.24, 1.0],
#  'MortgageTaxRelief': [0.3, 0.54, 1.0],
#  'NationalBusinessCouncil': [0.43, 0.01, 0.85],
#  'NationalService': [0.68, 0.58, 0.95],
#  'Newcarsubsidies': [0.24, 0.53, 0.38],
#  'OrganicSubsidy': [1.0, 0.47, 0.17],
#  'PayrollTax': [0.77, 1.0, 0.5],
#  'PetrolTax': [0.19, 0.0, 0.56],
#  'PhoneTapping': [0.38, 0.81, 0.01],
#  'PoliceDrones': [0.0, 0.22, 0.51],
#  'PoliceForce': [0.99, 0.43, 0.68],
#  'PollutionControls': [0.45, 0.33, 1.0],
#  'PressFreedom': [0.49, 1.0, 0.87],
#  'PrisonRegime': [0.55, 0.89, 0.03],
#  'PrisonerTagging': [0.44, 0.26, 1.0],
#  'PrisonerVoting': [0.73, 0.04, 1.0],
#  'PrivatePrisons': [0.52, 0.41, 0.91],
#  'PropertyTax': [0.41, 0.64, 0.0],
#  'ProportionalFines': [0.93, 0.01, 0.3],
#  'Punitivetaxonsuperstores': [0.26, 0.62, 0.0],
#  'RaceDiscriminationAct': [0.67, 0.38, 1.0],
#  'RareEarthRefinement': [0.0, 0.99, 0.86],
#  'Reforestation': [0.47, 0.22, 0.85],
#  'RightToPrivacy': [0.47, 0.74, 0.26],
#  'RoboticsResearch': [0.56, 0.22, 0.0],
#  'SmartMeterProgram': [0.38, 0.0, 1.0],
#  'SocialJusticeFoundation': [0.89, 1.0, 0.33],
#  'StateEnergy': [0.53, 0.11, 1.0],
#  'StatePensions': [0.19, 0.39, 0.03],
#  'StateRail': [1.0, 0.0, 0.41],
#  'StateTelecoms': [0.7, 0.16, 1.0],
#  'StateWater': [0.97, 0.01, 0.37],
#  'SyntheticMeatResearchGrants': [0.0, 1.0, 0.72],
#  'Tasers': [0.93, 0.0, 0.36],
#  'TechnologyColleges': [0.78, 0.59, 0.46],
#  'TelecommutingInitiative': [0.0, 0.45, 1.0],
#  'TobaccoTax': [0.24, 1.0, 0.47],
#  'TortureUsageBySecretServices': [0.99, 0.51, 0.0],
#  'Tradeunionbansatcompanies': [0.27, 1.0, 0.0],
#  'UnemployedBenefit': [0.06, 0.39, 1.0],
#  'UniversalBasicIncome': [0.07, 0.18, 1.0],
#  'UniversityGrants': [0.95, 0.57, 0.67],
#  'VerticalFarmSubsidies': [0.28, 0.04, 1.0],
#  'WaterCannon': [0.44, 0.11, 1.0],
#  'WinterFuelSubsidy': [0.68, 0.0, 0.81],
#  'WitnessProtectionProgram': [0.0, 0.4, 0.2],
#  'YoungEntrepreneurScheme': [0.1, 0.82, 0.98],
#  'YouthClubSubsidies': [0.83, 0.0, 0.58],
#  'bantobacco': [0.58, 0.34, 1.0],
#  'desalination': [0.34, 0.61, 0.89],
#  'religioustax': [0.0, 0.67, 0.17],
#  'statereligion': [0.0, 0.55, 0.12]}

# %%
len(disagree)
# Out:
# 213

# %%
# Take the values they agree on and try to find an optimum for metrics where they don't
from pyswarm import pso
import numpy as np

def optimize_situations_with_fixed_policies(all_relationships, situations, all_agree, disagree):
    last_10_scores = []
    last_100_scores = []
    
    def objective_function_pso(x, *args):
        nonlocal last_10_scores, last_100_scores
        optimized_policy_values = {key: round(x[i], 2) for i, key in enumerate(tweakable_policy_factors)}
        complete_policy_values = {**optimized_policy_values, **fixed_policy_values}
        
        situation_score = 0
        reset_metrics = None

        for i in range(2):
            situation_score = 0
            for situation, attributes in situations.items():
                situation_value = compute_metric(situation, all_relationships, complete_policy_values, metrics_values, reset_metrics=reset_metrics)
                if situation_value >= all_relationships[situation]['start_trigger']:
                    if not attributes['positive']:
                        situation_score += 1  # Maximize the negative to minimize negatives
            
            reset_metrics = set(metrics_values.keys())
            
        last_10_scores.append(situation_score)
        last_100_scores.append(situation_score)
        
        if len(last_10_scores) > 10:
            last_10_scores.pop(0)
            
        if len(last_100_scores) > 100:
            last_100_scores.pop(0)
        
        avg_10 = round(sum(last_10_scores) / len(last_10_scores), 2)    
        avg_100 = round(sum(last_100_scores) / len(last_100_scores), 2)
        
        print(f"Current Score: {situation_score}, Avg last 10: {avg_10}, Avg last 100: {avg_100}")        

        
        return situation_score

    all_connected_factors = set()
    for situation in situations.keys():
        find_connected_factors(situation, all_relationships, all_connected_factors)

    tweakable_policy_factors = [factor for factor in all_connected_factors if all_relationships[factor].get('type') == 'policy' and factor in disagree.keys()]
    fixed_policy_factors = [factor for factor in all_connected_factors if factor in all_agree.keys()]

    fixed_policy_values = {key: np.mean(all_agree[key]) for key in fixed_policy_factors}

    lb = [0 for _ in tweakable_policy_factors]
    ub = [1 for _ in tweakable_policy_factors]
    metrics_values = {"_globaleconomy_": 0.5, "_default_": 0.5, "_year": 0.5}

    xopt, fopt = pso(objective_function_pso, lb, ub, args=(), swarmsize=100, omega=0.5, phip=0.5, phig=1.0, maxiter=10000, minstep=0.01, minfunc=0.01, debug=False)

    optimized_values = {key: round(xopt[i], 2) for i, key in enumerate(tweakable_policy_factors)}
    optimized_values.update(fixed_policy_values)

    bad_situations = []
    reset_metrics = None

    for i in range(2):
        situation_score = 0
        for situation, attributes in situations.items():
            situation_value = compute_metric(situation, all_relationships, optimized_values, metrics_values, reset_metrics=reset_metrics)
            if situation_value >= all_relationships[situation]['start_trigger']:
                if not attributes['positive']:
                    bad_situations.append((situation, situation_value))

        reset_metrics = set(metrics_values.keys())

    final_score = fopt

    return optimized_values, final_score, bad_situations

optimized_values, final_score, bad_situations = optimize_situations_with_fixed_policies(all_relationships, situations, all_agree, disagree)
print("Optimized Values:", optimized_values)
print("Bad Situations:", bad_situations)
print("Final Score:", final_score)
# Out:
# Current Score: 8, Avg last 10: 8.0, Avg last 100: 8.0
# Current Score: 13, Avg last 10: 10.5, Avg last 100: 10.5
# Current Score: 11, Avg last 10: 10.67, Avg last 100: 10.67
# Current Score: 11, Avg last 10: 10.75, Avg last 100: 10.75
# Current Score: 12, Avg last 10: 11.0, Avg last 100: 11.0
# Current Score: 14, Avg last 10: 11.5, Avg last 100: 11.5
# Current Score: 11, Avg last 10: 11.43, Avg last 100: 11.43
# Current Score: 11, Avg last 10: 11.38, Avg last 100: 11.38
# Current Score: 10, Avg last 10: 11.22, Avg last 100: 11.22
# Current Score: 10, Avg last 10: 11.1, Avg last 100: 11.1
# Current Score: 10, Avg last 10: 11.3, Avg last 100: 11.0
# Current Score: 13, Avg last 10: 11.3, Avg last 100: 11.17
# Current Score: 12, Avg last 10: 11.4, Avg last 100: 11.23
# Current Score: 10, Avg last 10: 11.3, Avg last 100: 11.14
# Current Score: 14, Avg last 10: 11.5, Avg last 100: 11.33
# Current Score: 12, Avg last 10: 11.3, Avg last 100: 11.38
# Current Score: 12, Avg last 10: 11.4, Avg last 100: 11.41
# Current Score: 10, Avg last 10: 11.3, Avg last 100: 11.33
# Current Score: 14, Avg last 10: 11.7, Avg last 100: 11.47
# Current Score: 11, Avg last 10: 11.8, Avg last 100: 11.45
# Current Score: 9, Avg last 10: 11.7, Avg last 100: 11.33
# Current Score: 12, Avg last 10: 11.6, Avg last 100: 11.36
# Current Score: 11, Avg last 10: 11.5, Avg last 100: 11.35
# Current Score: 14, Avg last 10: 11.9, Avg last 100: 11.46
# Current Score: 11, Avg last 10: 11.6, Avg last 100: 11.44
# Current Score: 9, Avg last 10: 11.3, Avg last 100: 11.35
# Current Score: 11, Avg last 10: 11.2, Avg last 100: 11.33
# Current Score: 13, Avg last 10: 11.5, Avg last 100: 11.39
# Current Score: 11, Avg last 10: 11.2, Avg last 100: 11.38
# Current Score: 13, Avg last 10: 11.4, Avg last 100: 11.43
# Current Score: 11, Avg last 10: 11.6, Avg last 100: 11.42
# Current Score: 12, Avg last 10: 11.6, Avg last 100: 11.44
# Current Score: 14, Avg last 10: 11.9, Avg last 100: 11.52
# Current Score: 13, Avg last 10: 11.8, Avg last 100: 11.56
# Current Score: 9, Avg last 10: 11.6, Avg last 100: 11.49
# Current Score: 9, Avg last 10: 11.6, Avg last 100: 11.42
# Current Score: 12, Avg last 10: 11.7, Avg last 100: 11.43
# Current Score: 10, Avg last 10: 11.4, Avg last 100: 11.39
# Current Score: 13, Avg last 10: 11.6, Avg last 100: 11.44
# Current Score: 6, Avg last 10: 10.9, Avg last 100: 11.3
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 3.19
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 3.19
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 3.18
# Current Score: 4, Avg last 10: 2.9, Avg last 100: 3.17
# Current Score: 3, Avg last 10: 2.9, Avg last 100: 3.17
# Current Score: 4, Avg last 10: 3.1, Avg last 100: 3.18
# Current Score: 2, Avg last 10: 3.0, Avg last 100: 3.17
# Current Score: 3, Avg last 10: 3.0, Avg last 100: 3.17
# Current Score: 3, Avg last 10: 3.0, Avg last 100: 3.16
# Current Score: 3, Avg last 10: 3.1, Avg last 100: 3.15
# Current Score: 2, Avg last 10: 3.0, Avg last 100: 3.13
# Current Score: 3, Avg last 10: 3.0, Avg last 100: 3.13
# Current Score: 2, Avg last 10: 2.9, Avg last 100: 3.12
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 3.11
# Current Score: 4, Avg last 10: 2.8, Avg last 100: 3.12
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 3.1
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 3.1
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 3.1
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 3.1
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 3.1
# Current Score: 3, Avg last 10: 2.8, Avg last 100: 3.1
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 3.09
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 3.07
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 3.05
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 3.05
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 3.05
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 3.04
# Current Score: 4, Avg last 10: 2.7, Avg last 100: 3.04
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 3.04
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 3.02
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 3.02
# Current Score: 3, Avg last 10: 2.8, Avg last 100: 3.01
# Current Score: 4, Avg last 10: 3.0, Avg last 100: 3.01
# Current Score: 3, Avg last 10: 3.1, Avg last 100: 3.01
# Current Score: 4, Avg last 10: 3.2, Avg last 100: 3.01
# Current Score: 4, Avg last 10: 3.3, Avg last 100: 3.01
# Current Score: 3, Avg last 10: 3.4, Avg last 100: 3.01
# Current Score: 4, Avg last 10: 3.4, Avg last 100: 3.01
# Current Score: 3, Avg last 10: 3.4, Avg last 100: 3.01
# Current Score: 3, Avg last 10: 3.4, Avg last 100: 3.0
# Current Score: 3, Avg last 10: 3.4, Avg last 100: 3.0
# Current Score: 2, Avg last 10: 3.3, Avg last 100: 2.99
# Current Score: 2, Avg last 10: 3.1, Avg last 100: 2.98
# Current Score: 3, Avg last 10: 3.1, Avg last 100: 2.98
# Current Score: 3, Avg last 10: 3.0, Avg last 100: 2.98
# Current Score: 2, Avg last 10: 2.8, Avg last 100: 2.98
# Current Score: 3, Avg last 10: 2.8, Avg last 100: 2.98
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.98
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.98
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.98
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.98
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.97
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.96
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.96
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.95
# ...
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.54
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.54
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.54
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.54
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.54
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.3, Avg last 100: 2.54
# Current Score: 3, Avg last 10: 2.3, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.3, Avg last 100: 2.54
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.54
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.3, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.3, Avg last 100: 2.52
# Current Score: 3, Avg last 10: 2.3, Avg last 100: 2.52
# Current Score: 2, Avg last 10: 2.3, Avg last 100: 2.51
# Current Score: 3, Avg last 10: 2.3, Avg last 100: 2.51
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.51
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.51
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.51
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.52
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.52
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.52
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.52
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.52
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 2.52
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.51
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.51
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.51
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.51
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.51
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.51
# Current Score: 3, Avg last 10: 2.8, Avg last 100: 2.51
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 2.51
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.5
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.5
# Current Score: 3, Avg last 10: 2.8, Avg last 100: 2.5
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 2.5
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.5
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.5
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.5
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.51
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.52
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.51
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.51
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.5
# {'TechnologyColleges': 0.59, 'TradeCouncil': 0.1, 'LaborDayBankHoliday': 0.52, 'WitnessProtectionProgram': 0.4, 'PrisonerTagging': 0.26, 'ScienceFunding': 0.94, 'ConsumerRights': 0.61, 'UniversityGrants': 0.57, 'StemCells': 0.29, 'UnemployedBenefit': 0.39, 'Tasers': 0.0, 'Nationalanthematstartofnews': 0.0, 'SmallBusinessGrants': 0.72, 'FoodStandards': 0.0, 'StateEnergy': 0.11, 'StatePensions': 0.39, 'MandatoryMicrochipImplant': 0.0, 'KeepTheCountryTidyCampaign': 0.0, 'PetrolTax': 0.0, 'CarTax': 0.21, 'MinimumWage': 0.32, 'NationalService': 0.58, 'ChildcareProvision': 0.55, 'PoliceDrones': 0.22, 'StateHealthService': 0.0, 'Gambling': 1.0, 'RoadBuilding': 0.78, 'DriverlessCarLaws': 1.0, 'PropertyTax': 0.64, 'NationalBusinessCouncil': 0.01, 'CongestionCharging': 0.0, 'Narcotics': 0.82, 'OrganDonation': 0.99, 'IntelligenceServices': 0.62, 'PrivatePrisons': 0.41, 'AgricultureSubsidies': 0.54, 'FemaleGenitalMutilationBan': 0.75, 'PollutionControls': 0.33, 'BorderControls': 0.15, 'PhoneTapping': 0.81, 'AlcoholLaw': 1.0, 'desalination': 0.61, 'LabourLaws': 0.33, 'RoboticsResearch': 0.22, 'bansocialmedia': 1.0, 'MarsProgram': 0.82, 'MicrogenerationGrants': 0.01, 'LuxuryGoodsTax': 0.34, 'GenderDiscriminationAct': 0.86, 'BusLanes': 0.73, 'TechnologyGrants': 0.37, 'statereligion': 0.55, 'ExecutiveTermLength': 0.64, 'SocialJusticeFoundation
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.5
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.49
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.49
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.49
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.5
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.51
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.52
# Current Score: 4, Avg last 10: 2.7, Avg last 100: 2.53
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.54
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.54
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.54
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.8, Avg last 100: 2.57
# Current Score: 3, Avg last 10: 2.9, Avg last 100: 2.57
# Current Score: 3, Avg last 10: 2.9, Avg last 100: 2.57
# Current Score: 2, Avg last 10: 2.8, Avg last 100: 2.57
# Current Score: 3, Avg last 10: 2.8, Avg last 100: 2.57
# Current Score: 3, Avg last 10: 2.8, Avg last 100: 2.57
# Current Score: 2, Avg last 10: 2.8, Avg last 100: 2.57
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.3, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.3, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.3, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.3, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.56
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.57
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.58
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.58
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.58
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.58
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.57
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.57
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.57
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.57
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 2.57
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.57
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.56
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.3, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.55
# Current Score: 2, Avg last 10: 2.3, Avg last 100: 2.54
# Current Score: 3, Avg last 10: 2.3, Avg last 100: 2.54
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.54
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.53
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.53
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.3, Avg last 100: 2.52
# Current Score: 3, Avg last 10: 2.3, Avg last 100: 2.52
# Current Score: 2, Avg last 10: 2.3, Avg last 100: 2.52
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.52
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.52
# Current Score: 2, Avg last 10: 2.3, Avg last 100: 2.52
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.53
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.53
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.52
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.52
# Current Score: 4, Avg last 10: 2.7, Avg last 100: 2.52
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.52
# Current Score: 3, Avg last 10: 2.8, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.8, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.53
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.53
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.7, Avg last 100: 2.52
# Current Score: 2, Avg last 10: 2.6, Avg last 100: 2.52
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.52
# Current Score: 4, Avg last 10: 2.5, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.52
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.52
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.52
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.53
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.54
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.53
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.53
# Current Score: 3, Avg last 10: 2.7, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.52
# Current Score: 3, Avg last 10: 2.6, Avg last 100: 2.53
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.52
# Current Score: 2, Avg last 10: 2.5, Avg last 100: 2.51
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.5
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.49
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.49
# Current Score: 3, Avg last 10: 2.5, Avg last 100: 2.49
# Current Score: 2, Avg last 10: 2.4, Avg last 100: 2.49
# Current Score: 3, Avg last 10: 2.4, Avg last 100: 2.49

# %%
len(some_agree)
# Out:
# 99

# %%
import json
import numpy as np

# Compute the average for each policy in all_agree array and round to 2 decimals
avg_all_agree = {key: round(np.mean(values), 2) for key, values in all_agree.items()}

# Load current French policies
with open("results/current_french_policies.json", 'r') as f:
    current_policies = json.load(f)

# Compare current policies with average "all_agree" values and print if difference is > 0.1
for key, current_value in current_policies.items():
    if key in avg_all_agree:
        avg_value = avg_all_agree[key]
        if abs(current_value - avg_value) > 0.1:
            print(f"{key}: Current Value = {current_value}, Suggested Value = {avg_value}")
# Out:
# CapitalGainsTax: Current Value = 0.18, Suggested Value = 0.0
# CarEmmissionsLimits: Current Value = 0.5, Suggested Value = 0.0
# CCTVCameras: Current Value = 0.3, Suggested Value = 1.0
# CharityTaxRelief: Current Value = 0.34, Suggested Value = 0.9
# CleanEnergySubsidies: Current Value = 0.1, Suggested Value = 0.73
# DivertedProfitsTax: Current Value = 0.52, Suggested Value = 0.68
# InheritanceTax: Current Value = 0.4, Suggested Value = 0.22
# JudiciaryIndependence: Current Value = 0.85, Suggested Value = 0.48
# MaternityLeave: Current Value = 0.3, Suggested Value = 0.0
# MilitarySpending: Current Value = 0.55, Suggested Value = 0.97
# Prisons: Current Value = 0.4, Suggested Value = 0.86
# SelectiveSchooling: Current Value = 0.5, Suggested Value = 0.0
# StateHousing: Current Value = 0.45, Suggested Value = 0.55
# TollRoads: Current Value = 0.66, Suggested Value = 0.97
# WorkersOnBoards: Current Value = 0.33, Suggested Value = 0.0

# %%
# Load minimize_negative-2.json values
with open("results/pso/minimize_negative-2.json", 'r') as f:
    minimize_negative = json.load(f)

# Compare current policies with minimize_negative values and print if difference is > 0.1
for key, current_value in current_policies.items():
    if key in minimize_negative:
        min_value = minimize_negative[key]
        if abs(current_value - min_value) > 0.1:
            print(f"{key}: Current Value = {current_value}, Suggested Value = {min_value}")
# Out:
# AdultEducationSubsidies: Current Value = 0.6, Suggested Value = 0.97
# AgricultureSubsidies: Current Value = 0.7, Suggested Value = 0.54
# AirlineTax: Current Value = 0.02, Suggested Value = 0.44
# AlcoholLaw: Current Value = 0.5, Suggested Value = 1.0
# AntibioticsBan: Current Value = 0.6, Suggested Value = 0.74
# AntiCorruptionAgency: Current Value = 0.5, Suggested Value = 0.0
# BanSundayShopping: Current Value = 0.1, Suggested Value = 0.31
# BicycleSubsidies: Current Value = 0.1, Suggested Value = 0.88
# BiofuelSubsidies: Current Value = 0.5, Suggested Value = 0.93
# BorderControls: Current Value = 0.5, Suggested Value = 0.15
# BusLanes: Current Value = 0.6, Suggested Value = 0.73
# BusSubsidies: Current Value = 0.25, Suggested Value = 0.95
# CapitalGainsTax: Current Value = 0.18, Suggested Value = 0.0
# CarbonTax: Current Value = 0.29, Suggested Value = 1.0
# CarEmmissionsLimits: Current Value = 0.5, Suggested Value = 0.0
# CCTVCameras: Current Value = 0.3, Suggested Value = 0.995
# CharityTaxRelief: Current Value = 0.34, Suggested Value = 0.9
# ChildBenefit: Current Value = 0.4, Suggested Value = 1.0
# CitizenshipTests: Current Value = 0.25, Suggested Value = 0.0
# CleanEnergySubsidies: Current Value = 0.1, Suggested Value = 0.7250000000000001
# CommunityPolicing: Current Value = 0.25, Suggested Value = 0.91
# ConsumerRights: Current Value = 0.5, Suggested Value = 0.61
# CorporationTax: Current Value = 0.62, Suggested Value = 0.0
# DisabilityBenefit: Current Value = 0.83, Suggested Value = 0.36
# DivertedProfitsTax: Current Value = 0.52, Suggested Value = 0.675
# DrugTreatment: Current Value = 0.75, Suggested Value = 0.0
# DrugEnforcement: Current Value = 0.5, Suggested Value = 0.62
# ElectricCarsInitiative: Current Value = 0.1, Suggested Value = 0.94
# ExecutiveTermLength: Current Value = 0.5, Suggested Value = 0.64
# ExecutiveTermLimit: Current Value = 0.0, Suggested Value = 0.63
# FamilyPlanning: Current Value = 0.5, Suggested Value = 1.0
# FoodStandards: Current Value = 0.5, Suggested Value = 0.0
# ForeignAid: Current Value = 0.45, Suggested Value = 1.0
# FreeSchoolMeals: Current Value = 0.25, Suggested Value = 0.64
# Gambling: Current Value = 0.1, Suggested Value = 1.0
# GameHunting: Current Value = 0.5, Suggested Value = 0.96
# GayMarriage: Current Value = 0.5, Suggested Value = 1.0
# GenderDiscriminationAct: Current Value = 0.5, Suggested Value = 0.86
# GenderTransition: Current Value = 0.5, Suggested Value = 0.07
# HandgunLaws: Current Value = 0.5, Suggested Value = 0.99
# HybridCarsInitiative: Current Value = 0.25, Suggested Value = 0.5
# IDCards: Current Value = 0.5, Suggested Value = 0.18
# IncomeTax: Current Value = 0.46, Suggested Value = 0.04
# InheritanceTax: Current Value = 0.4, Suggested Value = 0.22
# IntellectualPropertyRights: Current Value = 0.85, Suggested Value = 0.01
# JudiciaryIndependence: Current Value = 0.85, Suggested Value = 0.48
# JunkFoodTax: Current Value = 0.5, Suggested Value = 1.0
# LabourLaws: Current Value = 0.95, Suggested Value = 0.33
# LegalAid: Current Value = 0.75, Suggested Value = 0.99
# LegaliseProstitution: Current Value = 0.25, Suggested Value = 0.05
# LimitAutomatedTrading: Current Value = 0.01, Suggested Value = 0.35
# MansionTax: Current Value = 0.45, Suggested Value = 0.29
# MarriedTaxAllowance: Current Value = 0.25, Suggested Value = 0.69
# MaternityLeave: Current Value = 0.3, Suggested Value = 0.0
# MicrogenerationGrants: Current Value = 0.5, Suggested Value = 0.01
# MilitarySpending: Current Value = 0.55, Suggested Value = 0.97
# MinimumWage: Current Value = 0.55, Suggested Value = 0.32
# MortgageTaxRelief: Current Value = 0.25, Suggested Value = 0.54
# Narcotics: Current Value = 0.0, Suggested Value = 0.82
# NuclearFission: Current Value = 0.84, Suggested Value = 0.11
# NuclearWeapons: Current Value = 0.66, Suggested Value = 1.0
# OrganDonation: Current Value = 0.5, Suggested Value = 0.99
# OrganicSubsidy: Current Value = 0.75, Suggested Value = 0.47
# PayrollTax: Current Value = 0.85, Suggested Value = 1.0
# PetrolTax: Current Value = 0.51, Suggested Value = 0.0
# PollutionControls: Current Value = 0.5, Suggested Value = 0.33
# PressFreedom: Current Value = 0.85, Suggested Value = 1.0
# PrisonRegime: Current Value = 0.3, Suggested Value = 0.89
# Prisons: Current Value = 0.4, Suggested Value = 0.86
# PropertyTax: Current Value = 0.88, Suggested Value = 0.64
# PublicLibraries: Current Value = 0.5, Suggested Value = 0.73
# RaceDiscriminationAct: Current Value = 0.5, Suggested Value = 0.38
# RacialProfiling: Current Value = 0.25, Suggested Value = 0.12
# RightToPrivacy: Current Value = 0.5, Suggested Value = 0.74
# RoadBuilding: Current Value = 0.48, Suggested Value = 0.78
# RubberBullets: Current Value = 0.75, Suggested Value = 1.0
# SalesTax: Current Value = 0.55, Suggested Value = 0.15
# SchoolBuses: Current Value = 0.61, Suggested Value = 0.31
# ScienceFunding: Current Value = 0.48, Suggested Value = 0.94
# SelectiveSchooling: Current Value = 0.5, Suggested Value = 0.0
# SmallBusinessGrants: Current Value = 0.1, Suggested Value = 0.72
# SmartMeterProgram: Current Value = 0.81, Suggested Value = 0.0
# StateBroadcaster: Current Value = 0.5, Suggested Value = 1.0
# StateEnergy: Current Value = 0.45, Suggested Value = 0.11
# StateHealthService: Current Value = 0.64, Suggested Value = 0.0
# StateHousing: Current Value = 0.45, Suggested Value = 0.55
# StatePensions: Current Value = 0.78, Suggested Value = 0.39
# StatePostService: Current Value = 0.5, Suggested Value = 0.75
# StateRail: Current Value = 0.55, Suggested Value = 0.0
# StateSchools: Current Value = 0.64, Suggested Value = 0.0
# StateTelecoms: Current Value = 0.65, Suggested Value = 0.16
# TobaccoTax: Current Value = 0.27, Suggested Value = 1.0
# TollRoads: Current Value = 0.66, Suggested Value = 0.97
# UnemployedBenefit: Current Value = 0.75, Suggested Value = 0.39
# UniversityGrants: Current Value = 0.1, Suggested Value = 0.57
# WorkersOnBoards: Current Value = 0.33, Suggested Value = 0.005

# %%
# Create a list of tuples containing the policy key, current value, and suggested value
discrepancies = []
for key, current_value in current_policies.items():
    if key in minimize_negative:
        min_value = minimize_negative[key]
        if abs(current_value - min_value) > 0.1:
            discrepancies.append((key, current_value, min_value))

# Sort the list by the absolute distance of suggested value from 0.5, in descending order
discrepancies.sort(key=lambda x: abs(x[2] - 0.5), reverse=True)

# Print the sorted list
for key, current_value, suggested_value in discrepancies:
    print(f"{key}: Current Value = {current_value}, Suggested Value = {suggested_value}")
# Out:
# AlcoholLaw: Current Value = 0.5, Suggested Value = 1.0
# AntiCorruptionAgency: Current Value = 0.5, Suggested Value = 0.0
# CapitalGainsTax: Current Value = 0.18, Suggested Value = 0.0
# CarbonTax: Current Value = 0.29, Suggested Value = 1.0
# CarEmmissionsLimits: Current Value = 0.5, Suggested Value = 0.0
# ChildBenefit: Current Value = 0.4, Suggested Value = 1.0
# CitizenshipTests: Current Value = 0.25, Suggested Value = 0.0
# CorporationTax: Current Value = 0.62, Suggested Value = 0.0
# DrugTreatment: Current Value = 0.75, Suggested Value = 0.0
# FamilyPlanning: Current Value = 0.5, Suggested Value = 1.0
# FoodStandards: Current Value = 0.5, Suggested Value = 0.0
# ForeignAid: Current Value = 0.45, Suggested Value = 1.0
# Gambling: Current Value = 0.1, Suggested Value = 1.0
# GayMarriage: Current Value = 0.5, Suggested Value = 1.0
# JunkFoodTax: Current Value = 0.5, Suggested Value = 1.0
# MaternityLeave: Current Value = 0.3, Suggested Value = 0.0
# NuclearWeapons: Current Value = 0.66, Suggested Value = 1.0
# PayrollTax: Current Value = 0.85, Suggested Value = 1.0
# PetrolTax: Current Value = 0.51, Suggested Value = 0.0
# PressFreedom: Current Value = 0.85, Suggested Value = 1.0
# RubberBullets: Current Value = 0.75, Suggested Value = 1.0
# SelectiveSchooling: Current Value = 0.5, Suggested Value = 0.0
# SmartMeterProgram: Current Value = 0.81, Suggested Value = 0.0
# StateBroadcaster: Current Value = 0.5, Suggested Value = 1.0
# StateHealthService: Current Value = 0.64, Suggested Value = 0.0
# StateRail: Current Value = 0.55, Suggested Value = 0.0
# StateSchools: Current Value = 0.64, Suggested Value = 0.0
# TobaccoTax: Current Value = 0.27, Suggested Value = 1.0
# CCTVCameras: Current Value = 0.3, Suggested Value = 0.995
# WorkersOnBoards: Current Value = 0.33, Suggested Value = 0.005
# HandgunLaws: Current Value = 0.5, Suggested Value = 0.99
# IntellectualPropertyRights: Current Value = 0.85, Suggested Value = 0.01
# LegalAid: Current Value = 0.75, Suggested Value = 0.99
# MicrogenerationGrants: Current Value = 0.5, Suggested Value = 0.01
# OrganDonation: Current Value = 0.5, Suggested Value = 0.99
# AdultEducationSubsidies: Current Value = 0.6, Suggested Value = 0.97
# MilitarySpending: Current Value = 0.55, Suggested Value = 0.97
# TollRoads: Current Value = 0.66, Suggested Value = 0.97
# IncomeTax: Current Value = 0.46, Suggested Value = 0.04
# GameHunting: Current Value = 0.5, Suggested Value = 0.96
# LegaliseProstitution: Current Value = 0.25, Suggested Value = 0.05
# BusSubsidies: Current Value = 0.25, Suggested Value = 0.95
# ElectricCarsInitiative: Current Value = 0.1, Suggested Value = 0.94
# ScienceFunding: Current Value = 0.48, Suggested Value = 0.94
# BiofuelSubsidies: Current Value = 0.5, Suggested Value = 0.93
# GenderTransition: Current Value = 0.5, Suggested Value = 0.07
# CommunityPolicing: Current Value = 0.25, Suggested Value = 0.91
# CharityTaxRelief: Current Value = 0.34, Suggested Value = 0.9
# NuclearFission: Current Value = 0.84, Suggested Value = 0.11
# PrisonRegime: Current Value = 0.3, Suggested Value = 0.89
# StateEnergy: Current Value = 0.45, Suggested Value = 0.11
# BicycleSubsidies: Current Value = 0.1, Suggested Value = 0.88
# RacialProfiling: Current Value = 0.25, Suggested Value = 0.12
# GenderDiscriminationAct: Current Value = 0.5, Suggested Value = 0.86
# Prisons: Current Value = 0.4, Suggested Value = 0.86
# BorderControls: Current Value = 0.5, Suggested Value = 0.15
# SalesTax: Current Value = 0.55, Suggested Value = 0.15
# StateTelecoms: Current Value = 0.65, Suggested Value = 0.16
# IDCards: Current Value = 0.5, Suggested Value = 0.18
# Narcotics: Current Value = 0.0, Suggested Value = 0.82
# InheritanceTax: Current Value = 0.4, Suggested Value = 0.22
# RoadBuilding: Current Value = 0.48, Suggested Value = 0.78
# StatePostService: Current Value = 0.5, Suggested Value = 0.75
# AntibioticsBan: Current Value = 0.6, Suggested Value = 0.74
# RightToPrivacy: Current Value = 0.5, Suggested Value = 0.74
# BusLanes: Current Value = 0.6, Suggested Value = 0.73
# PublicLibraries: Current Value = 0.5, Suggested Value = 0.73
# CleanEnergySubsidies: Current Value = 0.1, Suggested Value = 0.7250000000000001
# SmallBusinessGrants: Current Value = 0.1, Suggested Value = 0.72
# MansionTax: Current Value = 0.45, Suggested Value = 0.29
# BanSundayShopping: Current Value = 0.1, Suggested Value = 0.31
# SchoolBuses: Current Value = 0.61, Suggested Value = 0.31
# MarriedTaxAllowance: Current Value = 0.25, Suggested Value = 0.69
# MinimumWage: Current Value = 0.55, Suggested Value = 0.32
# DivertedProfitsTax: Current Value = 0.52, Suggested Value = 0.675
# LabourLaws: Current Value = 0.95, Suggested Value = 0.33
# PollutionControls: Current Value = 0.5, Suggested Value = 0.33
# LimitAutomatedTrading: Current Value = 0.01, Suggested Value = 0.35
# DisabilityBenefit: Current Value = 0.83, Suggested Value = 0.36
# ExecutiveTermLength: Current Value = 0.5, Suggested Value = 0.64
# FreeSchoolMeals: Current Value = 0.25, Suggested Value = 0.64
# PropertyTax: Current Value = 0.88, Suggested Value = 0.64
# ExecutiveTermLimit: Current Value = 0.0, Suggested Value = 0.63
# DrugEnforcement: Current Value = 0.5, Suggested Value = 0.62
# RaceDiscriminationAct: Current Value = 0.5, Suggested Value = 0.38
# ConsumerRights: Current Value = 0.5, Suggested Value = 0.61
# StatePensions: Current Value = 0.78, Suggested Value = 0.39
# UnemployedBenefit: Current Value = 0.75, Suggested Value = 0.39
# UniversityGrants: Current Value = 0.1, Suggested Value = 0.57
# AirlineTax: Current Value = 0.02, Suggested Value = 0.44
# StateHousing: Current Value = 0.45, Suggested Value = 0.55
# AgricultureSubsidies: Current Value = 0.7, Suggested Value = 0.54
# MortgageTaxRelief: Current Value = 0.25, Suggested Value = 0.54
# OrganicSubsidy: Current Value = 0.75, Suggested Value = 0.47
# JudiciaryIndependence: Current Value = 0.85, Suggested Value = 0.48
# HybridCarsInitiative: Current Value = 0.25, Suggested Value = 0.5

# %%
# Create a list of tuples containing the policy key and suggested value for keys only in all_agree
exclusive_keys = []
for key, avg_value in minimize_negative.items():
    if key not in current_policies and key not in avg_all_agree:
        exclusive_keys.append((key, avg_value))

# Sort the list by the suggested value, in descending order
exclusive_keys.sort(key=lambda x: x[1], reverse=True)

# Print the sorted list
for key, suggested_value in exclusive_keys:
    print(f"{key}: Suggested Value = {suggested_value}")
# Out:
# DriverlessCarLaws: Suggested Value = 1.0
# bansocialmedia: Suggested Value = 1.0
# SocialJusticeFoundation: Suggested Value = 1.0
# SolidarityTax: Suggested Value = 1.0
# banwomendriving: Suggested Value = 1.0
# TearGas: Suggested Value = 1.0
# CyclingCampaign: Suggested Value = 1.0
# Tradeunionbansatcompanies: Suggested Value = 1.0
# packagingtax: Suggested Value = 1.0
# SyntheticMeatResearchGrants: Suggested Value = 1.0
# Compulsorylanguagelessons: Suggested Value = 0.99
# RareEarthRefinement: Suggested Value = 0.99
# watermeters: Suggested Value = 0.98
# FreeEyeTests: Suggested Value = 0.98
# InternetCensorship: Suggested Value = 0.97
# FinancialTransactionsTax: Suggested Value = 0.97
# bancrypto: Suggested Value = 0.96
# competitionlaw: Suggested Value = 0.96
# DiplomaticService: Suggested Value = 0.92
# YouthPoliticsCouncil: Suggested Value = 0.87
# Publicreligiousbroadcasts: Suggested Value = 0.86
# Publictaxreturns: Suggested Value = 0.83
# MarsProgram: Suggested Value = 0.82
# YoungEntrepreneurScheme: Suggested Value = 0.82
# PhoneTapping: Suggested Value = 0.81
# InternetCurrencyTaxation: Suggested Value = 0.81
# BanSecondHomeOwnership: Suggested Value = 0.81
# AlcoholAwarenessCampaign: Suggested Value = 0.8
# GovernmentSubsidiesForUnions: Suggested Value = 0.8
# ClimateChangeAdaptionFund: Suggested Value = 0.8
# CompulsoryFoodLabelling: Suggested Value = 0.8
# CityFarms: Suggested Value = 0.78
# AbortionLaw: Suggested Value = 0.78
# GeneralMediaCensorship: Suggested Value = 0.77
# FemaleGenitalMutilationBan: Suggested Value = 0.75
# CleanFuelSubsidy: Suggested Value = 0.75
# Compulsorychurchattendance: Suggested Value = 0.73
# workersdividend: Suggested Value = 0.72
# Flagsoneverystreetcorner: Suggested Value = 0.69
# TaxShelters: Suggested Value = 0.69
# co2campaign: Suggested Value = 0.69
# religioustax: Suggested Value = 0.67
# Forcepoliticalmilitaryreligiousoath: Suggested Value = 0.66
# SpeedCameras: Suggested Value = 0.63
# Punitivetaxonsuperstores: Suggested Value = 0.62
# desalination: Suggested Value = 0.61
# RightToDie: Suggested Value = 0.6
# BorderWall: Suggested Value = 0.6
# FaithSchoolSubsidies: Suggested Value = 0.6
# ForeignInvestorTaxBreaks: Suggested Value = 0.6
# TechnologyColleges: Suggested Value = 0.59
# NationalService: Suggested Value = 0.58
# ChildcareProvision: Suggested Value = 0.55
# statereligion: Suggested Value = 0.55
# BodyCameras: Suggested Value = 0.55
# TobaccoAwarenessCampaign: Suggested Value = 0.55
# Newcarsubsidies: Suggested Value = 0.53
# Closeairportscompletely: Suggested Value = 0.52
# FoodStamps: Suggested Value = 0.52
# TortureUsageBySecretServices: Suggested Value = 0.51
# Banforeignchurchservice: Suggested Value = 0.5
# InternetTax: Suggested Value = 0.49
# Limitorbancarsincities: Suggested Value = 0.46
# TelecommutingInitiative: Suggested Value = 0.45
# OilDrillingSubsidy: Suggested Value = 0.44
# RefugeePolicy: Suggested Value = 0.44
# GatedCommunities: Suggested Value = 0.43
# Banlowmpgcars: Suggested Value = 0.42
# PrivatePrisons: Suggested Value = 0.41
# WitnessProtectionProgram: Suggested Value = 0.4
# TechnologyGrants: Suggested Value = 0.37
# Curfews: Suggested Value = 0.36
# LuxuryGoodsTax: Suggested Value = 0.34
# Banhomosexuality: Suggested Value = 0.33
# FuelEfficiency: Suggested Value = 0.25
# Monorail: Suggested Value = 0.24
# PoliceDrones: Suggested Value = 0.22
# RoboticsResearch: Suggested Value = 0.22
# Reforestation: Suggested Value = 0.22
# CarTax: Suggested Value = 0.21
# JuryTrial: Suggested Value = 0.18
# StateAirline: Suggested Value = 0.18
# UniversalBasicIncome: Suggested Value = 0.18
# WaterCannon: Suggested Value = 0.11
# HealthTaxCredits: Suggested Value = 0.11
# TradeCouncil: Suggested Value = 0.1
# CapCEOPayMultiplier: Suggested Value = 0.1
# Banprivatehealthcare: Suggested Value = 0.09
# CarPoolingCampaign: Suggested Value = 0.08
# Creationism: Suggested Value = 0.07
# HealthFoodSubsidies: Suggested Value = 0.07
# VerticalFarmSubsidies: Suggested Value = 0.04
# PrisonerVoting: Suggested Value = 0.04
# RecreationalDrugsTax: Suggested Value = 0.03
# NationalBusinessCouncil: Suggested Value = 0.01
# bordernavy: Suggested Value = 0.01
# EnterpriseInvestmentScheme: Suggested Value = 0.01
# ProportionalFines: Suggested Value = 0.01
# RentControls: Suggested Value = 0.01
# Recycling: Suggested Value = 0.01
# StateWater: Suggested Value = 0.01
# Tasers: Suggested Value = 0.0
# Nationalanthematstartofnews: Suggested Value = 0.0
# MandatoryMicrochipImplant: Suggested Value = 0.0
# KeepTheCountryTidyCampaign: Suggested Value = 0.0
# CongestionCharging: Suggested Value = 0.0
# FrequentFlyerTax: Suggested Value = 0.0
# ImmigrationRules: Suggested Value = 0.0
# WinterFuelSubsidy: Suggested Value = 0.0
# EmptyHomesTax: Suggested Value = 0.0
# Banprivateeducation: Suggested Value = 0.0
# GraduateTax: Suggested Value = 0.0
# Nationalanthemsinschool: Suggested Value = 0.0
# GreenElectronicsInitiative: Suggested Value = 0.0
# HealthyEatingCampaign: Suggested Value = 0.0
# FlatTax: Suggested Value = 0.0
# DetentionWithoutTrial: Suggested Value = 0.0
# RuralDevelopmentGrants: Suggested Value = 0.0
# YouthClubSubsidies: Suggested Value = 0.0
# SecretCourts: Suggested Value = 0.0
# HumanCloningResearchGrants: Suggested Value = 0.0
